# %%
#  @title html

# %%html
<!-- auto refresh page after 30sec -->
  <meta http-equiv="refresh" content="30"/>
<!-- viewport
  The viewport is the user's visible area of a web page.
  The viewport varies with the device, and will be smaller on a mobile phone than on a computer screen.-->
  <meta name="viewport" content="width=device-width,initial-scale=1.0">
    width=device-width //sets the width of the page to follow the screen-width of the device (which will vary depending on the device).
    initial-scale=1.0 //sets the initial zoom level when the page is first loaded by the browser.
<script> 
 Events---
  ontoggle =" dothis()" //	Fires when the user opens or closes the <details> element//  <details>
  // <body>
    onafterprint=" dothis()" //	Script to be run after the document is printed
    onbeforeprint	=" dothis()" //		Script to be run before the document is printed
    onbeforeunload	=" dothis()" //		ask user before leaving the tab or page with alert()      
    onhashchange	=" dothis()" //		Script to be run when there has been changes to the anchor part of the a URL
    onload	=" dothis()" //		Fires after the page is finished loading
      //	<body, <frame, <frameset, <iframe, <img, <input type="image", <link, <script and <style
    onmessage	=" dothis()" //		Script to be run when the message is triggered
    onoffline	=" dothis()" //		Script to be run when the browser starts to work offline
    ononline	=" dothis()" //		Script to be run when the browser starts to work online
    onpagehide	=" dothis()" //		Script to be run when a user navigates away from a page
    onpageshow	=" dothis()" //		Script to be run everytime when a user navigates to a page or reload page
      //The onpageshow event is similar to the onload event, except that it occurs after the onload event
      //when the page first loads. Also, the onpageshow event occurs every time the page is loaded, whereas
      //the onload event does not occur when the page is loaded from the cache.
    onpopstate	=" dothis()" //		Script to be run when the window's history changes
    onresize	=" dothis()" //		Fires when the browser window is resized
    onstorage	=" dothis()" //		Script to be run when a Web Storage area is updated
    onunload	=" dothis()" //Fires once a page has unloaded,the browser window has been closed, by clicking on a link, submitting a form, closing the browser window, page reload  etc.)
    onerror	=" dothis()" //	Script to be run when an error occurs when the file is being loaded
      // <audio><body><embed><img><link><object><script><video>
  //All HTML elements, EXCEPT: <base>, <bdo>, <br>, <head>, <html>, <iframe>, <meta>, <param>, <script>, <style>, and <title>
    onblur	=" dothis()" //	Fires the moment that the element loses focus or when the user leaves a form field
    onfocus	=" dothis()" //	Fires the moment when the element gets focus
      //All HTML elements, EXCEPT: <base>, <bdo>, <br>, <head>, <html>, <iframe>, <meta>, <param>, <script>, <style>, and <title>
    onchange	=" dothis()" //	Fires the moment when the value of the element is changed// effects when element loss focus
      //<input type="checkbox" type="file" type="password" type="radio" type="range" type="search" type="text", <select and <textarea
    oninput	=" dothis()" //	Script to be run when an element gets user input// effects immediately 
      //	<input type="password" type="search" type="text" and <textarea
    oncontextmenu	=" dothis()" //	Script to be run when a context menu is triggered on right-click on that element
    oninvalid	=" dothis()" //	Script to be run when an element is invalid   //<input>
    onreset	=" dothis()"    //<form <input type="reset"
      //	Fires when the Reset button in a form is clicked 
    onsearch	=" dothis()" //	Fires when the user writes something in a search filled
      //The onsearch attribute fires when a user presses the "ENTER" key or clicks the "x" button in an <input> element with type="search".
      //	<input type="search">
    onselect	=" dothis()" //	Fires after some text has been selected by double-click on text in an element, mostly when you try to copy text
      //<input type="file" type="password" type="text", and <textarea
    onsubmit	=" dothis()" //	Fires when a form is submitted    //<form>

  Keyboard events //All HTML elements, EXCEPT: <base>, <bdo>, <br>, <head>, <html>, <iframe>, <meta>, <param>, <script>, <style>, and <title>
    onkeydown		=" dothis()" //		Fires when a user is pressing a key // works for all keys    
    onkeypress	=" dothis()" //		Fires when a user presses a key // not works for ALT, CTRL, SHIFT, ESC
    onkeyup		=" dothis()" //		Fires when a user releases a key // works for all keys
  Mouse events   // All HTML elements, EXCEPT: <base>, <bdo>, <br>, <head>, <html>, <iframe>, <meta>, <param>, <script>, <style>, and <title>
    onclick	=" dothis()" //	Fires on a mouse click on the element
    ondblclick	=" dothis()" //	Fires on a mouse double-click on the element
    onmousedown	=" dothis()" //	Fires when a mouse button is pressed down on an element
    onmouseup	=" dothis()" //	Fires when a mouse button is released over an element
    onmousemove	=" dothis()" //	Fires when the mouse pointer is moving while it is over an element
    onmouseover	=" dothis()" //	Fires when the mouse pointer moves over an element
    onmouseout	=" dothis()" //	Fires when the mouse pointer moves out of an element
    onwheel	=" dothis()" //	Fires when the mouse wheel rolls up or down over an element
  Drag events
    // Events fired on the draggable target (the source element):
    ondragstart	=" dothis()" //	Script to be run at the start of a drag operation
    ondrag	=" dothis()" //	Script to be run when an element is dragged// fires every 350 milliseconds.
    ondragend	=" dothis()" //	Script to be run at the end of a drag operation
    // Events fired on the drop target:
    ondragenter	=" dothis()" //	Script to be run when an element has been dragged to a valid drop target
    ondragleave	=" dothis()" //	Script to be run when an element leaves a valid drop target
    ondragover	=" dothis()" //	Script to be run when an element is being dragged over a valid drop target
    ondrop	=" dothis()" //	Script to be run when dragged element is being dropped
    // only for scrollbar
    onscroll	=" dothis()" //	Script to be run when an element's scrollbar is being scrolled
      // <address>, <blockquote>, <body>, <caption>, <center>, <dd>, <dir>, <div>, <dl>, <dt>, <fieldset>, <form>, <h1> to <h6>, <html>, <li>,
      // <menu>, <object>, <ol>, <p>, <pre>, <select>, <tbody>, <textarea>, <tfoot>, <thead>, <ul>
  Clipboard events
    oncopy	=" dothis()" //	Fires when the user copies the content of an element
    oncut	=" dothis()" //	Fires when the user cuts the content of an element
    onpaste	=" dothis()" //	Fires when the user pastes some content in an element
  Media events    //<audio>, <embed>, <img>, <object>, and <video>
    // During the loading process of an audio/video, the following events occur, in this order:
      // 1. loadstart
      // 2. durationchange
      // 3. loadedmetadata
      // 4. loadeddata
      // 5. progress
      // 6. canplay
      // 7. canplaythrough
    // Events triggered by medias like videos, images and audio (applies to all HTML elements, but is most common in media elements.)
    onabort	=" dothis()" //	Script to be run on abort
    // <audio><video> only
      oncanplay	=" dothis()" //	Script to be run when a file is ready to start playing (when it has buffered enough to begin)
      oncanplaythrough	=" dothis()" //	Script to be run when a file can be played all the way to the end without pausing for buffering
      ondurationchange	=" dothis()" //	Script to be run when the length of the media changes
      onemptied	=" dothis()" //	Script to be run when something bad happens and the file is suddenly unavailable (like unexpectedly disconnects)
      onended	=" dothis()" //	Script to be run when the media has reach the end (a useful event for messages like "thanks for listening")
      onloadeddata	=" dothis()" //	Script to be run when media data is loaded
      onloadedmetadata	=" dothis()" //	Script to be run when meta data (like dimensions and duration) are loaded
      onloadstart	=" dothis()" //	Script to be run just as the file begins to load before anything is actually loaded
      onpause	=" dothis()" //	Script to be run when the media is paused either by the user or programmatically
      onplay	=" dothis()" //	Script to be run when the media is ready to start playing
      onplaying	=" dothis()" //	Script to be run when the media actually has started playing
      onprogress	=" dothis()" //	Script to be run when the browser is in the process of getting the media data
      onratechange	=" dothis()" //	Script to be run each time the playback rate changes (like when a user switches to a slow motion or fast forward mode)
      oncuechange	=" dothis()" //	Script to be run when the cue changes in a <audio> or <video> <track>  </audio> or </video> element      
      onseeked	=" dothis()" //	Script to be run when the seeking attribute is set to false indicating that seeking has ended
      onseeking	=" dothis()" //	Script to be run when the seeking attribute is set to true indicating that seeking is active
      onstalled	=" dothis()" //	Script to be run when the browser is unable to fetch the media data for whatever reason
      onsuspend	=" dothis()" //	Script to be run when fetching the media data is stopped before it is completely loaded for whatever reason
      ontimeupdate	=" dothis()" //	Script to be run when the playing position has changed (like when the user fast forwards to a different point in the media)
      onvolumechange	=" dothis()" //	Script to be run each time the volume is changed which (includes setting the volume to "mute")
      onwaiting	=" dothis()" //	Script to be run when the media has paused but is expected to resume (like when the media pauses to buffer more data)
  
Attributes--
  Globals attributes
    accesskey="c"   //[Alt] + [c] will focus or select the element
      // value can be any a to z or 0 to 9//   a == A  // not caseSensitive
      //https://www.w3schools.com/tags/att_global_accesskey.asp
    class="class1 class2 class3"
      // The class attribute specifies one or more classnames for an element.
      // The class attribute is mostly used to point to a class in a style sheet or javascript.
    id='unique name'
    contenteditable="true" or "false"  //Specifies whether the content of an element is editable or not
      //When the contenteditable attribute is not set on an element, the element will inherit it from its parent.
    data-* ='any string as data' 
      //data-animal-type="bird"
      // works as attribute:value pair
      // * ->  should not contain any uppercase letters
      // The data-* attribute is used to store custom data private to the page or application.
      // The data-* attribute gives us the ability to embed custom data attributes on all HTML elements.
      // The stored (custom) data can then be used in the page's JavaScript to create a more engaging user experience (without any Ajax calls or server-side database queries).
      // The data-* attribute consist of two parts:
      // The attribute name should not contain any uppercase letters, and must be at least one character long after the prefix "data-"
      // The attribute value can be any string
      // Note: Custom attributes prefixed with "data-" will be completely ignored by the user agent.
    draggable="true"    //make the elemtnt to be draggable
      //"auto" ->	Uses the default behavior of the browser
      //Links and images are draggable by default.
    hidden      //hide the element
    lang="fr"     //specifies the language of the element's content.
      //"en" for English, "es" for Spanish, "fr" for French etc..
      //https://www.w3schools.com/tags/ref_language_codes.asp
    spellcheck="true"
      //specifies whether the element is to have its spelling and grammar checked or not.
      //Text values in input elements (not password)
      //Text in <textarea> elements
      //Text in editable elements
    style="color:blue;text-align:center"      //CSS for that perticular element
      //overrides any other css style
    tabindex="2"      //specifies the tab order when using [tab] key, the element will be focused on this order
    title="extra info"        //specifies extra information about an element when the mouse moves over the element.
    translate="no" or "yes"   //specifies whether we can translate the element text to another lang  not (use  class="notranslate" as translate is not supported)
  Other attributes
    alt='use this text in place of the image'   //<input type="image" src> <img src> <area href>
    accept="audio/*"   //<input type='file'>
      // The accept attribute specifies the types of files that the server accepts (that can be submitted through a file upload).
      //accept="video/*,image/*" //for multiple types, use ","
      //audio/*,video/*,image/*, .gif, .jpg, .png, .doc etc..        //http://www.iana.org/assignments/media-types/
    accept-charset ="ISO-8859-1"      //<form>
      // The accept-charset attribute specifies the character encodings that are to be used for the form submission.
      // The default value is the reserved string "UNKNOWN" (indicates that the encoding equals the encoding of the document containing the <form> element).
    action="server_url.php"     //<form>
      // The action attribute specifies where to send the form-data when a form is submitted.
    async  //<script>
      // The async attribute is a boolean attribute.
      // When present, it specifies that the script will be executed asynchronously as soon as it is available.
      // Note: The async attribute is only for external scripts (and should only be used if the src attribute is present).
      // Note: There are several ways an external script can be executed:
      //   If async is present: The script is executed asynchronously with the rest of the page (the script will be executed while the page continues the parsing)
      //   If async is not present and defer is present: The script is executed when the page has finished parsing
      //   If neither async or defer is present: The script is fetched and executed immediately, before the browser continues parsing the page
    autocomplete="off" or "on"      //<input types: text, search, url, tel, email, password, datepickers, range, color> and <form>
    autofocus   //<button><input>	<select>	<textarea>
      //focus on this input field to be typed
    autoplay    //<audio> <video>
    charset="UTF-8"     //<meta> <script>
      // specifies the character encoding
      //https://www.w3schools.com/charsets/default.asp
    checked // <input type="checkbox","radio">
      //pre-selected or pre-checked checkbox
    colspan="2"     //<td><th>
      //the number of columns a table cell should span.
    rowspan="2"     //<td><th>
      // specifies the number of rows a cell should span.
    content="value of name or http-equiv variable"      //<meta name or http-equiv>
      // gives the value associated with the http-equiv or name attribute.
    cols="10"     //<form><textarea>
      // 10 characters width
      //  visible width of a text area.
      // can also be set by the CSS height and width properties.
    rows="3"    //<form><textarea>
      // 3 lines height   (10*3=30 characters fully visible)
      //  visible height of a text area.
      // can also be set by the CSS height and width properties.
    controls    //<audio><video>
      //Play, Pause, Seeking, Volume,  Fullscreen toggle (video),  Captions/Subtitles (video),  Track (video)
    coords="0,0,82,126"     //<area>
      // The coords attribute specifies the coordinates of an area in an image map.
      // The coords attribute is used together with the shape attribute to specify the size, shape, and placement of an area.
      // Tip: The coordinates of the top-left corner of an area are 0,0.
    data="url_image.png"   //<object>
      //specifies the URL of the resource to be used by the object.
    default     //<track>
      // use this track as default
    defer    //<script src>
      // specifies that the script is executed when the page has finished parsing.
    disabled    // <button><fieldset><input><optgroup><option><select><textarea>
      // elemet will be non_interactive, no editing, no copy, , no typing, nothng
    download="optional filename"      //<a href > <area href >
      // specifies that the target will be downloaded when a user clicks on the hyperlink.
    enctype="multipart/form-data"         //<form method="post">
      "application/x-www-form-urlencoded"	//Default. All characters are encoded before sent (spaces are converted to "+" symbols, and special characters are converted to ASCII HEX values)
      "multipart/form-data"//	No characters are encoded. This value is required when you are using forms that have a file upload control
      "text/plain"	//Spaces are converted to "+" symbols, but no special characters are encoded
      // specifies how the form-data should be encoded when submitting it to the server.
    for="id"    //<label><output>
      //with  <label> element, the for attribute specifies which form element a label is bound to.
      //with <output> element, the for attribute specifies the relationship between the result of the calculation, and the elements used in the calculation.
    form='form_id'      //<button><fieldset><input><label><meter><object><output><select><textarea>
      // specifies the form the element belongs to.
      // The value of this attribute must be equal to the id attribute of a <form> element in the same document.
    formenctype="multipart/form-data"   //(<form method="post"> <input type="submit" or "image"> </form>)  
      'application/x-www-form-urlencoded'	//Default. All characters are encoded before sent (spaces are converted to "+" symbols, and special characters are converted to ASCII HEX values)
      'multipart/form-data'	//No characters are encoded
      'text/plain'	//Spaces are converted to "+" symbols, but no special characters are encoded
    formnovalidate or formnovalidate="formnovalidate" or formnovalidate=""   //(<form > <input type="submit" > </form>)  
      // do not validate the input data ,hence mistakes like invalid email will be submitted
    formtarget="_blank"    // (<form> <input type="submit" or "image"> </form>)  
      '_blank'  //	The response is displayed in a new window or tab (open up new window or tab)
      '_self'  //	The response is displayed in the (same frame) (this is default)
      '_parent'  //	The response is displayed in the (parent frame) 
      '_top'	//The response is displayed in the full body of the window (goes to next page)
      'framename'//	The response is displayed in a named iframe
      //overrides the target attribute of the form element.
      // specifies a name or a keyword that indicates where to display the response that is received after submitting the form.
    formmethod="post" or 'get'   // (<form> <input type="submit" or "image"> </form>)  
      //overrides <form  method='get' or 'post'>
    formaction='server.php'   // <button type="submit">  <input type="submit">
      //where to send form data when form is submitted
    headers="id"    //<td><th>
      // specifies one or more header cells a table cell is related to.
    height="20px"   // <input type="image"> <canvas><embed><iframe><img><<object><video>
    width="320"  // <input type="image"> <canvas><embed><iframe><img><<object><video>
      //pixel value
      // <iframe>  default is "300"
    min='0'     //<meter> <input types= number, range, date, datetime-local, month, time and week>
      //value should not be less than min
    low="40"     //<meter min="0" low="40" high="90" max="100" value="95"></meter>
    high="90"    //<meter min="0" low="40" high="90" max="100" value="95"></meter>
      //total range [min(0) , max(100)] and values from [low(40), high(90)] will be green, otherwise yellow.
      // specifies the range where the gauge's value is considered to be a high value.
      // The high attribute value must be less than the max attribute value, and it also must be greater than the low and min attribute values.
    max='100'   //<meter><progress> <input types= number, range, date, datetime-local, month, time and week>
      //value should not be more than max
      // <progress> element, the max attribute specifies how much work the task requires in total.
    href='url_of_file.png'  //<a><area><base><link>
      // For <a> and <area> elements, the href attribute specifies the URL of the page the link goes to.
      // For <base> elements, the href attribute specifies the base URL for all relative URLs on a page.
      // For <link> elements, the href attribute specifies the location (URL) of the external resource (most often a style sheet file).
    hreflang="en"     //<a><area><link>
      // specifies the language of the linked document.
    http-equiv="refresh"      //<meta content>
      // http-equiv attribute provides an HTTP header for the information/value of the content attribute.
      // The http-equiv attribute can be used to simulate an HTTP response header.
      "content-security-policy"	//Specifies a content policy for the document.    Example:  <meta http-equiv="content-security-policy" content="default-src 'self'">
      "content-type"	//Specifies the character encoding for the document.    Example:  <meta http-equiv="content-type" content="text/html; charset=UTF-8">
      "default-style" //	Specified the preferred style sheet to use.   Example:  <meta http-equiv="default-style" content="the document's preferred stylesheet">
        //Note: The value of the content attribute above must match the value of the title attribute
        // on a link element in the same document, or it must match the value of the title attribute on a style element in the same document.
      "refresh"	//Defines a time interval in seconds for the document to refresh itself.   //<meta http-equiv="refresh" content="30">
        // Note: The value "refresh" should be used carefully, as it takes the control of a page away from the user.
        // Using "refresh" will cause a failure in W3C's Web Content Accessibility Guidelines.
    ismap //<a href><img src ismap></a>
      // specifies that the image is part of a server-side image map (an image map is an image with clickable areas).
      // When clicking on a server-side image map, the click coordinates are sent to the server as a URL query string.
      // Note: The ismap attribute is allowed only if the <img> element is a descendant of an <a> element with a valid href attribute.
    kind='captions'   //<track>
      //  kind of text track.
      'captions'	//The track defines translation of dialogue and sound effects (suitable for deaf users)
      'chapters'	//The track defines chapter titles (suitable for navigating the media resource)
      'descriptions'	//The track defines a textual description of the video content (suitable for blind users)
      'metadata'	//The track defines content used by scripts. Not visible for the user
      'subtitles'	//The track defines subtitles, used to display subtitles in a video
    label="English"   //<track>
      // The label attribute specifies the title of the text track.
      // The title of the text track is used by the browser when listing available text tracks.
    list='datalist_id'     //(<input> <datalist id> <option value="option1 to put in input field"> </datalist>)
      // refers to a <datalist> element that contains pre-defined options for an <input> element.
    loop      //<audio><video>
    muted     //<video><audio>
    maxlength="10"     //<input><textarea>
      //you cannot type more than "10" character: default:524288
    minlength="8"      //<input type="text","search","url","tel", "email" and "password"
      //minimum characters to be typed
    media="devices operator (expresion)"   //<style><a href><area href><link><source>
      // devices
        'all'	Default. Suitable for all devices
        'aural'	Speech synthesizers
        'braille'	Braille feedback devices
        'handheld'	Handheld devices (small screen, limited bandwidth)
        'projection'	Projectors
        'print'	Print preview mode/printed pages
        'screen'	Computer screens
        'tty'	Teletypes and similar media using a fixed-pitch character grid
        'tv'	Television type devices (low resolution, limited scroll ability)
      // operator  any,many,all
        "and"// AND 
        "not"	// NOT
        ","	// OR
      // (expresion)
        'width'	Specifies the width of the targeted display area.   "min-" and "max-" prefixes can be used.   Example: media="screen and (min-width:500px)"
        'height'	Specifies the height of the  targeted display area.   "min-" and "max-" prefixes can be used.   Example: media="screen and (max-height:700px)"
        'device-width'	Specifies the width of the target display/paper.    "min-" and "max-" prefixes can be used.   Example: media="screen and (device-width:500px)"
        'device-height'	Specifies the height of the target display/paper.   "min-" and "max-" prefixes can be used.   Example: media="screen and (device-height:500px)"
        'orientation'	Specifies the orientation of the target display/paper.    Possible values: "portrait" or "landscape"    Example: media="all and (orientation: landscape)"
        'aspect-ratio'	Specifies the width/height ratio of the targeted display area.  "min-" and "max-" prefixes can be used.   Example: media="screen and (aspect-ratio:16/9)"
        'device-aspect-ratio'	Specifies the device-width/device-height ratio of the target display/paper.   "min-" and "max-" prefixes can be used.   Example: media="screen and (aspect-ratio:16/9)"
        'color'	Specifies the bits per color of target display. "min-" and "max-" prefixes can be used.   Example: media="screen and (color:3)"
        'color-index'	Specifies the number of colors the target display can handle.   "min-" and "max-" prefixes can be used.   Example: media="screen and (min-color-index:256)"
        'monochrome'	Specifies the bits per pixel in a monochrome frame buffer.  "min-" and "max-" prefixes can be used.   Example: media="screen and (monochrome:2)"
        'resolution'	Specifies the pixel density (dpi or dpcm) of the target display/paper.    "min-" and "max-" prefixes can be used.   Example: media="print and (resolution:300dpi)"
        'scan'	Specifies scanning method of a tv display.        Possible values are "progressive" and "interlace".        Example: media="tv and (scan:interlace)"
        'grid'	Specifies if the output device is grid or bitmap.       Possible values are "1" for grid, and "0" otherwise.        Example: media="handheld and (grid:1)"
      // specifies what media/device the linked  CSS style, target URL or document is optimized for.
      // pecify that the target URL is designed for special devices (like iPhone) , speech or print media.
      // This attribute can accept several values.
    method='post' or 'get'    // <form action>
    multiple    //<input types= "email" and "file"><select>
      //that the user is allowed to enter/select more than one value or files.
      //email: "mail1,mail2,mail3"   comma separated
    novalidate      //<form>
      // not to validate form-data and accept raw data like: email will not be checked even input is not a valid email
    name='abc'//<input><form><select><param><output><object><meta><fieldset><textarea>(<img usemap="#refer"> <map name="refer") (<iframe name="toHere"><a target="toHere")
      // it referes to the element, used as unique id but not the id
      //only elements having "name" att will be passed form-data to server and elements wihout "name" att will not be passed with that form-data
      //works as variable that holds the data of the element
      //If the http-equiv attribute is set, the name attribute should not be set.
    open    //<details>
      //specifies that the details should be visible (open) by default.
    pattern="[A-Za-z]{3}"      //<input types= text, date, search, url, tel, email, and password>
      //input should match the pattern
      //https://www.w3schools.com/js/js_regexp.asp
    placeholder="this text will show in the input field by default"   //<input types= text, search, url, tel, email, and password>  <textarea>
    poster="/images/w3html5.gif"    //<video>
      // as a thumbnail
      // The poster attribute specifies an image to be shown while the video is downloading, or 
      // until the user hits the play button. If this is not included, the first frame of the video will be used instead.
    preload="none"      //<audio><video>
      "auto"//	load the entire video when the page loads
      "metadata"	// load only metadata when the page loads
      "none"	// NOT load the video when the page loads
      //anything other than "none" will set the media to be preloaded.
      // The preload attribute specifies if and how the author thinks that the media file should be loaded when the page loads.
      // The preload attribute allows the author to provide a hint to the browser about what he/she thinks will lead to
      // the best user experience. This attribute may be ignored in some instances.
      // Note: The preload attribute is ignored if autoplay is present.
    readonly   //<input><textarea>
      //input field is not editable, but text can be copied from this field
    rel="a value here"    //<form><a href><area><link>
      //  relationship between the current document and the linked document/resource.
      // <a>
        'alternate'	//Provides a link to an alternate representation of the document (i.e. print page, translated or mirror)
        'author'	//Provides a link to the author of the document
        'bookmark'	//Permanent URL used for bookmarking
        'external'	//Indicates that the referenced document is not part of the same site as the current document
        'help'	//Provides a link to a help document
        'license'	//Provides a link to licensing information for the document
        'next'	//Provides a link to the next document
        'nofollow'	//Links to an unendorsed document, like a paid link. ("nofollow" is used by Google, to specify that the Google search spider should not follow that link)
        'noreferrer'	//Requires that the browser should not send an HTTP referer header if the user follows the hyperlink
        'noopener'	//Requires that any browsing context created by following the hyperlink must not have an opener browsing context
        'prev'	//The previous document in a selection
        'search'	//Links to a search tool for the document
        'tag'	//A tag (keyword) for the current document
      // <area>
        'alternate'	
        'author'	
        'bookmark'	
        'help'	
        'license'	
        'next'	
        'nofollow'	
        'noreferrer'	//Specifies that the browser should not send a HTTP referer header if the user follows the hyperlink
        'prefetch'	//Specifies that the target document should be cached
        'prev'	
        'search'	
        'tag'	
      // <link>
        'alternate'	//Provides a link to an alternate version of the document (i.e. print page, translated or mirror).
        'author'	//Provides a link to the author of the document
        'dns-prefetch'	//Specifies that the browser should preemptively perform DNS resolution for the target resource's origin
        'help'	//Provides a link to a help document. Example: <link rel="help" href="/help/">
        'icon'	//Imports an icon to represent the document.    Example: <link rel="icon" href="/favicon.ico" type="image/x-icon">
        'license'	//Provides a link to copyright information for the document
        'next'	//Provides a link to the next document in the series
        'pingback'	//Provides the address of the pingback server that handles pingbacks to the current document
        'preconnect'	//Specifies that the browser should preemptively connect to the target resource's origin.
        'prefetch'	//Specifies that the browser should preemptively fetch and cache the target resource as it is likely to be required for a follow-up navigation
        'preload'	//Specifies that the browser agent must preemptively fetch and cache the target resource for current navigation according to the destination given by the "as" attribute (and the priority associated with that destination).
        'prerender'	//Specifies that the browser should pre-render (load) the specified webpage in the background. So, if the user navigates to this page, it speeds up the page load (because the page is already loaded). Warning! This waste the user's bandwidth! Only use prerender if it is absolutely sure that the webpage is required at some point in the user journey
        'prev'	//Indicates that the document is a part of a series, and that the previous document in the series is the referenced document
        'search'	//Provides a link to a resource that can be used to search through the current document and its related pages.
        'stylesheet'	//Imports a style sheet
      // <form>
        'external'//	Specifies that the referenced document is not a part of the current site
        'help'//	Links to a help document
        'license'//	Links to copyright information for the document
        'next'//	The next document in a selection
        'nofollow'//	Links to an unendorsed document, like a paid link.("nofollow" is used by Google, to specify that the Google search spider should not follow that link)
        'noopener'	 
        'noreferrer'//	Specifies that the browser should not send a HTTP referrer header if the user follows the hyperlink
        'opener'	 
        'prev'//	The previous document in a selection
        'search'//	Links to a search tool for the document
    required   //<input types= text, search, url, tel, email, password, date pickers, number, checkbox, radio, and file> <textarea> <select>
      //must be filled or else it will not be submited
    reversed    //<ol>
      //  specifies that the list order should be descending (9,8,7...), instead of ascending (1, 2, 3...).
    sandbox or sandbox='allow-forms'    //<iframe>
      // enables an extra set of restrictions for the content in the iframe.
      (no value)	//Applies all restrictions
      'allow-forms'	//Allows form submission
      'allow-modals'	//Allows to open modal windows
      'allow-orientation-lock'//	Allows to lock the screen orientation
      'allow-pointer-lock'//	Allows to use the Pointer Lock API
      'allow-popups'	//Allows popups
      'allow-popups-to-escape-sandbox'//	Allows popups to open new windows without inheriting the sandboxing
      'allow-presentation'//	Allows to start a presentation session
      'allow-same-origin'	//Allows the iframe content to be treated as being from the same origin
      'allow-scripts'//	Allows to run scripts
      'allow-top-navigation'//	Allows the iframe content to navigate its top-level browsing context
      'allow-top-navigation-by-user-activation'//	Allows the iframe content to navigate its top-level browsing context, but only if initiated by user
      // it will:
        // treat the content as being from a unique origin
        // block form submission
        // block script execution
        // disable APIs
        // prevent links from targeting other browsing contexts
        // prevent content from using plugins (through <embed>, <object>, <applet>, or other)
        // prevent the content to navigate its top-level browsing context
        // block automatically triggered features (such as automatically playing a video or automatically focusing a form control)
        // The value of the sandbox attribute can either be just sandbox (then all restrictions are applied), or a space-separated list of pre-defined values that will REMOVE the particular restrictions.
    selected    //<option>
      // specifies that an option should be pre-selected when the page loads.
      // The pre-selected option will be displayed first in the drop-down list.
      // Tip: The selected attribute can also be set after the page loads, with a JavaScript.
    shape="circle"    //<area coords>
      // shape of an area
      'default'	//Specifies the entire region
      'rect'//	Defines a rectangular region
      'circle'	//Defines a circular region
      'poly'//	Defines a polygonal region
    list="idBrowsers">   //<input>
      //only with datalist element      <input list>
      <datalist id="idBrowsers">      //a pre-defined list of options to be used as an input value
        <option value="Internet Explorer">
        <option value="Firefox">
        </datalist
    size="50"   //<input types= text, search, tel, url, email, and password>  <select>
      //width = '50 (characters) or (visible options in a drop-down list) will be fully visible'
      // For input elements, the size attribute specifies the visible width, in characters, of an <input> element.
      // For select elements, the size attribute specifies the number of visible options in a drop-down list.
    sizes="16x16 32x32"   //<link rel='icon'>
      // sizes of icons for visual media.
      'HeightxWidth'	//Specifies one or more sizes for the linked icon.      The height and width values are separated by an "x" or "X".
        Examples:
          <link rel="icon" href="favicon.png" sizes="16x16" type="image/png">         //(1 size)
          <link rel="icon" href="favicon.png" sizes="16x16 32x32" type="image/png">   //(2 sizes)
      'any'	    //Specifies that the icon is scalable (like an SVG image)   
        Examples:
          <link rel="icon" href="icon.svg" sizes="any" type="image/svg+xml"> (any size)
    span='2'  //<col><colgroup>
      //  defines the number of columns a <col>/<colgroup> element should span.
    src='path or url of the file'   //<audio><embed><iframe><img><input type='image' ><script><source><track><video>
    srcdoc='<p> valid HTML syntax to show in iframe </p>'   //<iframe>
      // specifies the HTML content of the page to show in the inline frame.
      // Tip: This attribute is expected to be used together with the sandbox and seamless attributes.
      // If a browser supports the srcdoc attribute, it will override the content specified in the src attribute (if present).
      // If a browser does NOT support the srcdoc attribute, it will show the file specified in the src attribute instead (if present).
    srclang="en"    //<track kind>
      // the language of the track text data.
      // https://www.w3schools.com/tags/ref_language_codes.asp
    srcset="img_pink_flowers.jpg"     //<picture><source srcset="img_pink_flowers.jpg"></picture>
    start="50"    //<ol>
      // specifies the start value of the first list item in an ordered list.
      // This value is always an integer, even when the numbering type is letters or romans. 
      // E.g., to start counting list items from the letter "c" or the roman number "iii", use start="3".
    step='3'   //<input types= number, range, date, datetime-local, month, time and week>
      //only value%3==0 are valid
    target='_blank'     //<a><area><base><form>
      '_blank'//	Opens the linked document in a new window or tab
      '_self'	//Opens the linked document in the same frame as it was clicked (this is default)
      '_parent'	//Opens the linked document in the parent frame
      '_top'	//Opens the linked document in the full body of the window
      'name of the frame'	//Opens the linked document in a named frame    <iframe name='somehting'>
      <a> or <area> // specifies where to open the linked document.
      <base> // specifies the default target for all hyperlinks and forms in the page.
      <form> // specifies a name or a keyword that indicates where to display the response that is received after submitting the form.
    type="submit"   //<a href><input><button><embed><link rel><object><style><script><source>
      <input> // specifies the type of <input> element to display.
        // default is "text"
        'button'	// a clickable button (mostly used with a JavaScript to activate a script)
        'checkbox'	// a checkbox
        'color'	// a color picker
        'date'	// a date control (year, month, day (no time))
        'datetime-local'	// a date and time control (year, month, day, time (no timezone)
        'email'	// a field for an e-mail address
        'file'	// a file-select field and a "Browse" button (for file uploads)
        'hidden'	// a hidden input field
        'image'	// an image as the submit button
        'month'	// a month and year control (no timezone)
        'number'	// a field for entering a number
        'password'	// a password field
        'radio'	// a radio button
        'range'	// a range control (like a slider control)
        'reset'	// a reset button  (resets the form-data to its initial values)
        'search'	// a text field for entering a search string
        'submit'	// a submit button (submits form-data)
        'tel'	// a field for entering a telephone number
        'text'	 // a single-line text field // Default:text
        'time'	// a control for entering a time (no timezone)
        'url'	// a field for entering a URL
        'week'	// a week and year control (no timezone)
      <button> // specifies the type of button.
        'button'	// a clickable button (mostly used with a JavaScript to activate a script)
        'submit'	// a submit button (submits form-data)
        'reset'	// a reset button  (resets the form-data to its initial values)
      //Internet media type (formerly known as MIME type).
        // http://www.iana.org/assignments/media-types/
        <a href>
        <embed>
        <link rel>
        <object>
        <style> //default is "text/css"
        <script> //default is "application/javascript" (and optional "application/ecmascript")
        <source> //Common media types:
          // For video:   video/ogg,    video/mp4,    video/webm
          // For audio:   audio/ogg,    audio/mpeg
    usemap="#name of the map"   //(  (<object> or <img>)    <map name="mymapname">  )
      // specifies the name of an image map to use with the object or image.
      // An image map is an image with clickable areas.
      // The usemap attribute is associated with a <map> element's name or id attribute, and creates a relationship between the (<img> or <object>) and the <map>.
      // Note: The usemap attribute cannot be used if the <img> element is a descendant of an <a> or <button> element.    
    value='default value of the field'   //<input type> <button> (<select><option></select>) (<object><param name></object>) (<ol><li></ol>) <meter> <progress> 
      <input>
        type= "button", "reset", "submit"// it defines the text ON the button. (for display purpose only)
        type= "text", "password", "hidden"// specifies the initial value OF the input field.(for display and to be send to server, mutable by user)
        type= "checkbox", "radio", "image"// it defines the value OF the input field. (for display and to be send to server, immutable by user)
      <button> , <option> // specifies the value OF the element. (for display and to be send to server, immutable by user)
      <li> //<ol value>  sets the starting index of the <ol> lists. (for display purpose only)
      <meter> //specifies the current value of the gauge. value attribute must be between the min and max attribute values.
      <progress> // specifies how much of the task has been completed.
      <param name> // specifies the value OF the parameter.
Elements---
  <form
    //attributes
      accept-charset
      action
      autocomplete
      enctype
      method
      name
      novalidate
      rel
      target  >
    //elements
      <input>
      <textarea>    //multi-line text input   
      <button>
      <select>
      <option>
      <optgroup>
      <fieldset>
      <label>
      <legend>
      <datalist>
      <output>
    </form>
  //Button
    <button>Default Button</button>
    <a href="#" class="button">Link Button</a>
    <input type="button" class="button" value="Input Button">
  <select name id      // <form>
    // a drop-down list to select from, only used with form
    //attributes
      form
      multiple
      size> //	number	Defines the number of visible options in a drop-down list
    // elements
    <option value="mercedes">Mercedes</option>
    <option value="audi">Audi</option>
    </select>

# %%
#@title mimeType
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Basics_of_HTTP/MIME_types
# https://developer.mozilla.org/en-US/docs/Web/HTTP/Basics_of_HTTP/MIME_types/Common_types

videoCodecs:  MKV	
audioCodecs: OPUS/VORBIS

audio/webm
audio/webm;codecs=pcm
audio/wav
audio/ogg
audio/pcm

video/webm
video/webm;codecs=vp9
video/webm;codecs=vp8
video/webm;codecs=h264
video/x-matroska;codecs=avc1
video/mpeg
video/mp4

image/gif

# %%
#  @title CSS ->  stands for Cascading Style 
# %%html
<head><style>
 /* comment */
External CSS ->  <head><link rel="stylesheet" href="mystyle.css"></head>
  /* you can change the look of an entire website by changing just one file!
  Each HTML page must include a reference to the external style sheet file inside the <link> element, inside the head section. */
Internal CSS ->  <head><style>    css code    < /style></head>
  /* may be used if one single HTML page has a unique style.
  defined inside the style element, inside the head section. */
Inline CSS  ->   <h1 style="color:blue;text-align:center;">  This is a heading  </h1>
  /* An inline style may be used to apply a unique style for a single element.
  To use inline styles, add the style attribute to the relevant element. The style attribute can contain any CSS property. */

selector { declaratoin block
            property : value;
            property : value;
}   
h1 {
  align-content
  align-items
  align-self
  all
  animation
    animation-delay
    animation-direction
    animation-duration
    animation-fill-mode
    animation-iteration-count
    animation-name
    animation-play-state
    animation-timing-function
  backface-visibility
  background: #ffffff url("img_tree.png") no-repeat fixed right top;// (color image repeat attachment position)
    background-color: lightblue;    //text background-color
    background-image: url("paper.gif"),url("paper2.gif"),url("dog.gif");   // small image repeates itself. any element can have its own background-image
    background-repeat: repeat-y;  // y: To repeat an image vertically, x: To repeat an image horizonatally, no-repeat: single image once
    background-attachment: fixed;// or scroll  // to scroll or not to scroll with the page
    background-position: right top; //specify the position of the background image.	
    background-blend-mode:normal;//	This is default. Sets the blending mode to normal	
      multiply//	Sets the blending mode to multiply	// when using multiple bacckgrounds
      screen	//Sets the blending mode to screen	
      overlay	//Sets the blending mode to overlay	
      darken	//Sets the blending mode to darken	
      lighten	//Sets the blending mode to lighten	
      color-dodge//	Sets the blending mode to color-dodge	
      saturation	//Sets the blending mode to saturation	
      color	//Sets the blending mode to color	
      luminosity//	Sets the blending mode to luminosity
    background-clip:border-box;//	Default value. The background extends behind the border	
      padding-box//	The background extends to the inside edge of the border	
      content-box	//The background extends to the edge of the content box	
      initial	//Sets this property to its default value. Read about initial	
      inherit	//Inherits this property from its parent element. Read about inherit
    background-origin:padding-box;//	Default value. The background image starts from the upper left corner of the padding edge	
      border-box//	The background image starts from the upper left corner of the border	
      content-box	//The background image starts from the upper left corner of the content	
      initial	//Sets this property to its default value. Read about initial	
      inherit	//Inherits this property from its parent element. Read about inherit
    background-size:auto;//	Default value. The background image is displayed in its original size	
      px//	Sets the width and height of the background image. The first value sets the width, the second value sets the height. If only one value is given, the second is set to "auto". Read about length units	
      # %//	Sets the width and height of the background image in percent of the parent element. The first value sets the width, the second value sets the height. If only one value is given, the second is set to "auto"	
      cover//	Resize the background image to cover the entire container, even if it has to stretch the image or cut a little bit off one of the edges	
      contain//	Resize the background image to make sure the image is fully visible	
      initial	//Sets this property to its default value. Read about initial	
      inherit	//Inherits this property from its parent element. Read about inherit
  border: 2px solid DodgerBlue;  //(width,style,color)
    border-width: 25px 10px 4px 35px;  (top,right,bottom,left)
        // property specifies the width of the four borders.
        //units -> px, pt, cm, em  // :2px;
        //predefined vlues -> thin, medium, thick  // :thin ;
    border-style: dotted solid double dashed;//(top,right,bottom,left)
      border-top-style: dotted;
      border-right-style: solid;
      border-bottom-style: dotted;
      border-left-style: solid;
      dotted // Defines a dotted border
      dashed //Defines a dashed border
      solid // Defines a solid border
      double // Defines a double border
      groove // Defines a 3D grooved border. The effect depends on the border-color value
      ridge // Defines a 3D ridged border. The effect depends on the border-color value
      inset // Defines a 3D inset border. The effect depends on the border-color value
      outset // Defines a 3D outset border. The effect depends on the border-color value
      none // Defines no border
      hidden // Defines a hidden border 
    border-color: DodgerBlue;//(top,right,bottom,left) 
    border-image
      border-image-outset
      border-image-repeat
      border-image-slice
      border-image-source
      border-image-width
    border-bottom: 6px solid red;
      border-bottom-left-radius
      border-bottom-right-radius
      border-bottom-style
      border-bottom-width
    border-left: 6px solid red;
      border-left-color
      border-left-style
      border-left-width
    border-right
      border-right-color
      border-right-style
      border-right-width
    border-top
      border-top-color
      border-top-left-radius
      border-top-right-radius
      border-top-style
      border-top-width
    border-spacing
    border-radius: 5px;// rounded or circular border
    border-radius: 5%;// rounded or circular border corners		
    border-collapse
  bottom
  box-decoration-break
  box-shadow
  box-sizing: border-box;//   to keep the width , no matter what amount of padding is.
      content-box	//Default. only content area is inlcuded.
      border-box	// includes content + padding + border
      initial	//Sets this property to its default value. Read about initial
      inherit	//Inherits this property from its parent element. Read about inherit
  break-after
  break-before
  break-inside
  caption-side
  caret-color
  @charset
  clear
  clip
  clip-path
  color: white;       /*text color*/
    //color names > https://www.w3schools.com/colors/colors_names.asp    // color: white;
    //RGB  >  color: rgb(255, 99, 71);  or rgb(0%,0%,100%);   //(r,g,b)   0 ~ 255
    //HEX  >  color: #ff6347;             //#rrggbb    #000000 ~ #ffffff
    //HSL  >  color: hsl(9, 100%, 64%);     //(hue[0~360], saturation, lightness)
      //Hue is a degree on the color wheel from 0 to 360. 0 is red, 120 is green, and 240 is blue.
      //Saturation is a percentage value, 0% means a shade of gray, and 100% is the full color.
      //Lightness is also a percentage, 0% is black, 50% is neither light or dark, 100% is white
    //RGBA >  color: rgba(255, 99, 71, 0.5);    //alpha[0.0 ~ 1.0] -> transparency|opacity
    //HSLA >  color: hsla(9, 100%, 64%, 0.5);    //alpha[0.0 ~ 1.0] -> transparency|opacity 
    //HEXA  >  color: #ff63473A;             //#rrggbb aa[00 ~ ff] -> transparency|opacity
    //currentcolor  > border: 10px solid currentcolor; //Blue border color if  "color: blue;" is set */
  columns
    column-count
    column-fill
    column-gap
    column-rule
    column-rule-color
    column-rule-style
    column-rule-width
    column-span
    column-width
  content
  counter-increment
  counter-reset
  cursor: not-allowed;		// a disabled link or button
  direction
  display: inline;			// no <br> will be applied after this element
    block //element with <br> added
    inline-block // combination of both
    none //hides the element without taking the space, as space will be free
  visibility: hidden;		//hides the element but still taking the space as space will be consumed by this element even after hiding
    visible//	Default value. The element is visible	
    collapse//	Only for table rows (<tr>), row groups (<tbody>), columns (<col>), column groups (<colgroup>). This value removes a row or column, but it does not affect the table layout. The space taken up by the row or column will be available for other content.
          //If collapse is used on other elements, it renders as "hidden"
    initial	//Sets this property to its default value. Read about initial	
    inherit	//Inherits this property from its parent element. Read about inherit
  empty-cells
  filter
  flex
    flex-basis
    flex-direction
    flex-flow
    flex-grow
    flex-shrink
    flex-wrap
  float:left;
    left// The element floats to the left of its container
    right //The element floats to the right of its container
    none //The element does not float (will be displayed just where it occurs in the text). This is default
    inherit// The element inherits the float value of its parent
  font
    @font-face
    font-family: verdana;
    font-feature-settings
    font-kerning
    font-size: 20px;
    font-size-adjust
    font-stretch
    font-style
    font-variant
    font-variant-caps
    font-weight
  grid
    grid-area
    grid-auto-columns
    grid-auto-flow
    grid-auto-rows
    grid-column
    grid-column-end
    grid-column-gap
    grid-column-start
    grid-gap
    grid-row
    grid-row-end
    grid-row-gap
    grid-row-start
    grid-template
    grid-template-areas
    grid-template-columns
    grid-template-rows
  hanging-punctuation
  height:20px; //height of an element in px, cm etc.  (height = height + (top+bottom)padding + (top+bottom)border + (top+bottom)margin)
      height:auto;  //This is default. The browser calculates the height and width
      height: 20%;  //in percent% of the containing block
      height: initial; //to its default value
      height:inherit; //inherited from its parent value
      min-height: 20 ;//	Sets the minimum height of an element
      max-height:20;//	Sets the maximum height of an element
  width:30%;  //width of an element in px, cm etc.  (width = width + (left+right)padding + (left+right)border + (left+right)margin)
      width:auto;  //This is default. The browser calculates the height and width
      width: 20%;  //in percent% of the containing block
      width: initial; //to its default value
      width:inherit; //inherited from its parent value
      max-width: 20;// overides the width property    
      min-width:20;//	Sets the minimum width of an element
  hyphens
  @import
  isolation
  justify-content
  @keyframes
  left
  letter-spacing
  line-height
  list-style
  list-style-image
  list-style-position
  list-style-type
  margin:25px 50px 75px 100px;//(top, right, bottom, and left).// distance from parent's border
      margin-top: auto;  //the browser calculates the margin
      margin-bottom: 100px;  //specifies a margin in px, pt, cm, etc.
      margin-right: 30%;  //specifies a margin in % of the width of the containing element
      margin-left: inherit;  //specifies that the margin should be inherited from the parent element
  @media
  mix-blend-mode
  object-fit:fill;//This is default. The replaced content is sized to fill the element's content box. If necessary, the object will be stretched or squished to fit
    contain // The replaced content is scaled to maintain its aspect ratio while fitting within the element's content box
    cover // The replaced content is sized to maintain its aspect ratio while filling the element's entire content box. The object will be clipped to fit
    none //The replaced content is not resized
    scale-down// The content is sized as if none or contain were specified (would result in a smaller concrete object size)
  object-position
  opacity: 0.3;   // specifies the opacity/transparency of an entire element including its text. It can take a value from 0.0 - 1.0
  order
  outline: thick ridge pink;		//(width style color)
      /* Outline differs from borders! Unlike border, the outline is drawn outside the element's border,
      and may overlap other content. Also, the outline is NOT a part of the element's dimensions; the
      element's total width and height is not affected by the width of the outline. */
    outline-width:thin;
        /* thin (typically 1px)
        medium (typically 3px)
        thick (typically 5px)
        A specific size (in px, pt, cm, em, etc) */
      outline-style:dotted;
        /* dotted - Defines a dotted outline
        dashed - Defines a dashed outline
        solid - Defines a solid outline
        double - Defines a double outline
        groove - Defines a 3D grooved outline
        ridge - Defines a 3D ridged outline
        inset - Defines a 3D inset outline
        outset - Defines a 3D outset outline
        none - Defines no outline
        hidden - Defines a hidden outline */
      outline-color:red;
          /* name - specify a color name, like "red"
        HEX - specify a hex value, like "#ff0000"
        RGB - specify a RGB value, like "rgb(255,0,0)"
        HSL - specify a HSL value, like "hsl(0, 100%, 50%)"
        invert - performs a color inversion (which ensures that the outline is visible, regardless of color background)' */    
      outline-offset: 15px;
        //dds space between an outline and the edge/border of an element. The space between an element and its outline is transparent.
  overflow:auto;//whether to clip the content or to add scrollbars when the content of an element is too big to fit in the specified area.
    overflow-x:auto; // for left and right edges.
    overflow-y:auto; //for top and bottom edges.
    visible //Default. The overflow is not clipped. The content renders outside the element's box
    hidden //The overflow is clipped, and the rest of the content will be invisible
    scroll //The overflow is clipped, and a scrollbar is added to see the rest of the content
    auto //Similar to scroll, but it adds scrollbars only when necessary
    
  padding: 25px 50px 75px 100px;//(top, right, bottom,left) // distance from child's border|elements
      padding-top: auto;
      padding-right: 20px ;//specifies a padding in px, pt, cm, etc.
      padding-bottom: 30%; //specifies a padding in % of the width of the containing element
      padding-left: inherit;  //specifies that the padding should be inherited from the parent element
  page-break-after
  page-break-before
  page-break-inside
  perspective
  perspective-origin
  pointer-events
  position: static or relative or fixed or absolute or sticky;
  quotes
  resize:both;//	adds a resizing feature at the bottom-right corner of the element, same as <textarea>
    both//	The user can resize both the height and width of the element	
    horizontal//	The user can resize the width of the element	
    vertical	//The user can resize the height of the element	
    initial//	Sets this property to its default value. Read about initial	
    inherit	//Inherits this property from its parent element. Read about inherit
  right
  scroll-behavior: auto;//	Allows a straight jump "scroll effect" between elements within the scrolling box. This is default
    smooth//	Allows a smooth animated "scroll effect" between elements within the scrolling box.
    initial//	Sets this property to its default value. Read about initial
    inherit	//Inherits this property from its parent element. Read about inherit  
  tab-size
  table-layout
  text-align: left;//  [abc    ]
    right	//           [    abc]
    center	//         [  abc  ]
    justify//	         [ab dsfg] 
    text-align-last
    text-decoration:overline; //a roof over text^------
                    line-through // --strikethrough--
                    underline // linke a fill in the blanks ______
    text-decoration-color
    text-decoration-line
    text-decoration-style
    text-indent:50px; // space at the begining of the first line only
    text-justify
    text-overflow
    text-shadow
    text-transform:uppercase;//ABC
                   lowercase//abc
                   capitalize//Abc Def
  top
  transform
    transform-origin
    transform-style
  transition
    transition-delay
    transition-duration
    transition-property
    transition-timing-function
  unicode-bidi
  user-select
  vertical-align
  white-space:nowrap;//abc.\nabc.\nabc\n
              normal//abc.\nabc\n
                    //abc.\n
              pre;//abc.\n
                  //abc.\n
                  //abc.\n
  word-break
  word-spacing:noraml|5(px,cm,em);//ab    cde    f     gh
  word-wrap
  writing-mode
  z-index:1;    //postion of the element  // back < -inf to +inf  > front
}

/*Selector and its types types
  An id or class name cannot start with a number!*/
  Simple selectors /*(select elements based on name, id, class)*/
    #idname{}   /*all elements<> of idname will be affected*/
    .classname{}  /*all elements<> of classname will be affected8*/
    p.classname{} /*all <p> of classname will be affected*/
    *{}   /*all elements<> will be affected*/
    h1,h2,p {} /* only these elements will be affected regardless of the class or id*/
    // for <div><div><p><p><h> to access <h>
    // do this->  div div p p h{}
  Combinator selectors /* (select elements based on a specific relationship between them)*/
    div p{} // all <p> in one <div>; <div><p><p> <><p></> </div>
      /* descendant selector (space) */
    div > p {} // all <p> in one <div> excluding <div> <><p></> </div>
      /* child selector (>) */
    div + p {} //one <p> after one <div>, <div></div><p><p not this one or any other after this>
      /* adjacent sibling selector (+) */
    div ~ p{}  //all <p> after <div> , <div></div><p><p><p><p>...
      /* general sibling selector (~) */
  Pseudo-class selectors/* (select elements based on a certain state)*/
    /* Anchor */
      //these should be in this sequency to be more effective
      a:link {color: blue;}/* unvisited link */
      p:visited {color: purple;}/* visited link */
      h:hover {color: hotpink;}/* mouse over link */
      div:active {color: green;}/* selected link */
    p:first-child {}    //all first <p> of all and any element
    p i:first-child {}    //all the first <i> of all <p>
    p:first-child i {}    //all <i> of first <p>
    //see all at  https://www.w3schools.com/css/css_pseudo_classes.asp
  Pseudo-elements selectors/* (select and style a part of an element)*/
    p::first-line{}
    p::first-letter {}//first letter of all <p>
    p.intro::first-letter{}//first letter of all .intro classses of all <p>
    // for all https://www.w3schools.com/css/css_pseudo_elements.asp
  Attribute selectors# /*(select elements based on an attribute or attribute value)*/
    video[autoplay]{}   //all <video> with attribute autoplay set will be affected
    p[id="ppp"]{}   //all <p> with attributed id='ppp' will be affected
    [title~="flower"]{}//all or any element having "flower" in title attributes; title="klematis flower" and title="flower" etc..
    [lang|='en']	//all elements with a lang attribute value starting with "en"
    a[href^="https"]	//all <a> element whose href attribute value begins with "https"
    a[href$=".pdf"]	//all <a> element whose href attribute value ends with ".pdf"
    a[href*="w3schools"]	//all <a> element whose href attribute value contains the substring "w3schools"

//variables
  /* The variable name must begin with two dashes (--) and it is case sensitive! */
  //global scope
  :root { --varName: optionalValue if predefined variable not found as "blue" is predefined value for blue color;
    --blue: #1e90ff;
    --white: #ffffff; 
  }
  p{--blue: #0000ff;//overide the global var with local var value
    --green: #00ff00;//new local scope var
    color:var(--blue);}
  //with javascript
    var r = document.querySelector(':root');// Get the root element
    var rs = getComputedStyle(r);// Get the styles (properties and values) for the root
    rs.getPropertyValue('--blue')//get value of --blue
    r.style.setProperty('--blue', 'lightblue');// Set the value of variable --blue to another value (in this case "lightblue")
//@media media types
  /* width and height of the viewport
  width and height of the device
  orientation (is the tablet/phone in landscape or portrait mode?)
  resolution */
  @media and|not|only mediatype and (expressions) {   CSS-Code;   }
  //mediatype
    all	//Used for all media type devices
    print//	Used for printers
    screen//	Used for computer screens, tablets, smart-phones etc.
    speech//	Used for screenreaders that "reads" the page out loud
  //            and                    and                   or
  @media screen and (max-width: 900px) and (min-width: 600px) , (min-width: 1100px)  {    body {    background-color: lightgreen;   }   }
  @media only screen and (orientation: landscape) { css code;}
//postition   //top, bottom, left, and right properties will not work unless the position property is set first.
  p.relative{   //mostly use only one of (top,left) or (top,right) or (bottom,left) or (bottom,right)
    position: relative;// this property is must   //one of (static,relative,fixed,absolute,sticky)
    clip-path: circle(50%);   //show only 50% area
      //clip-source	Defines a URL to an SVG <clipPath> element	
      //basic-shape	Clips an element to a basic shape: circle, ellipse, polygon or inset	
      //margin-box	Uses the margin box as the reference box	 
      //border-box	Uses the border box as the reference box	 
      //padding-box	Uses the padding box as the reference box	 
      //content-box	Uses the content box as the reference box	 
      //fill-box	Uses the object bounding box as reference box	 
      //stroke-box	Uses the stroke bounding box as reference box	 
      //view-box	Uses the SVG viewport as reference box	 
      //none	This is default. No clipping is done	 
      //initial	Sets this property to its default value. Read about initial
      //inherit	Inherits this property from its parent element. Read about inherit
    bottom:	10px;//from bottom
    left:	-10cm;//from left
    right:	10%;//from right
    top:	-10;//from top
    z-index: 1;	//Sets the stack order of an element, (to back <- lower value)  and  ( higher value -> to front)  [back< -inf ~ +inf >front]
  }
  static    //HTML elements are positioned static by default. and not affected by top,left,bottom,right.
  relative  //affected by top, right, bottom, left to be adjusted away from its normal position.
  fixed  // always stays in the same place even if the page is scrolled. affected by top, right, bottom, left .
  absolute  //can be anyting except "static". its scope area is its parent(picture-in-picture like). affected by top, right, bottom, and left 
  sticky  //affected by top, right, bottom, and left 

//functions https://www.w3schools.com/cssref/css_functions.asp
h1{
  height:calc(80% - 100px);//can be used: + - * /
}

# %%
#  @title javascript
# %%javascript

let //can be updated but not redeclared in the same scope.
var //can be updated and redeclared in the same scope.
const //cannot be updated or redeclared in the same scope.

document.forms['form name here']['input name here'].checkValidity()// returns bool whether the form input data is valid or not.
  document.forms['form name here']['input name here'].validationMessage// returns validation message string like 'please fill the input.'
  .validity//	Contains boolean properties related to the validity of an input element.
    .validity.customError	//Set to true, if a custom validity message is set.
    .validity.patternMismatch	//Set to true, if an element's value does not match its pattern attribute.
    .validity.rangeOverflow	//Set to true, if an element's value is greater than its max attribute.
    .validity.rangeUnderflow//	Set to true, if an element's value is less than its min attribute.
    .validity.stepMismatch//	Set to true, if an element's value is invalid per its step attribute.
    .validity.tooLong	//Set to true, if an element's value exceeds its maxLength attribute.
    .validity.typeMismatch	//Set to true, if an element's value is invalid per its type attribute.
    .validity.valueMissing//	Set to true, if an element (with a required attribute) has no value.
    .validity.valid//	Set to true, if an element's value is valid.
  .validationMessage//	Contains the message a browser will display when the validity is false.
  .willValidate//	Indicates if an input element will be validated.

//HTML document, elements, attributes, values etc..
var html = document.documentElement//	Returns the <html> element
  var head = document.head	//Returns the <head> element
  var title = document.title	//Returns the <title> element
  var body = document.body//	Returns the <body> element
    document.body.replaceChild(document.createElement('p'), btn);     //replace <button> element with <p> element
    // create object
    var btn = document.createElement("BUTTON");  // <button> </button>
    var btn = document.querySelector('BUTTON')   // select first <button> element in the document
    var id = document.createAttribute('id')    // create attribute id object    //https://www.w3schools.com/tags/ref_attributes.asp
    // set
    var id = btn.attributes.setNamedItem(id)   // set attribute id without a value and return id object
    var id = btn.setAttributeNode(id)          // set attribute id without a value and return id object
    btn.setAttribute("class", "demo");         // set attribute id with a value     
    btn.id.value = 'button1'                   // set attribute id value
    btn.style.color = "red";                   // sets the text color to red        //https://www.w3schools.com/jsref/dom_obj_style.asp
    btn.innerText = "CLICK ME";                // <button> CLICK ME </button>
    document.body.appendChild(btn);            // <body> <button> CLICK ME </button> </body>
    // get
    var val = btn.getAttributeNode(btn.id)     // returns attribute id 
    var val = btn.getAttribute('id')           // returns attribute id value
    var val = btn.id.value                     // returns attribute id value
    var bool = btn.hasAttribute('id')          // returns bool whether or not the attibute id node is in the <button>
    var clr = btn.style.color                  // returns the text color of <button>
    // delete
    btn.attributes.removeNamedItem("id");      // deletes attribute id from element
    var id = btn.removeAttributeNode(btn.id)   // deletes attribute id from element
    btn.removeAttribute('id')                  // deletes attribute id from element   //https://www.w3schools.com/jsref/jsref_reference.asp
    btn.remove();                              // deletes the <button> element
    var btn = document.body.removeChild(btn)   // deletes and returns the <button> element object
    
    

btn.onclick = location.reload()     //reload the webpage

var x = document.readyState;
  uninitialized - Has not started loading yet
  loading - Is loading
  loaded - Has been loaded
  interactive - Has loaded enough and the user can interact with it
  complete - Fully loaded
//date and time
  // returns full date and time with browser's timezone-> Sun Nov 01 2020 17:10:04 GMT+0530 (India Standard Time)
  //JavaScript counts months from 0 to 11. So jan=0 and dec=11
  var d = new Date()
  var d = new Date(2018, 11, 24, 10, 33, 30, 0)//(year, month, day, hours, minutes, seconds, milliseconds)
  var d = new Date(3442343)//milliseconds
  var d = new Date("October 13, 2014 11:13:00")
  var ms = Date.parse("valid date string of supported formats")// to milliseconds.
  var ms = Date.now() // returns milliseconds
  Date.now()//	Get the time. ECMAScript 5.
  //methods
    d.toISOString()// ISO standard format-> 2020-11-01T11:50:06.860Z
    d.toUTCString()// UTC string-> Sun, 01 Nov 2020 11:48:55 GMT
    d.toDateString()// date string-> Sun Nov 01 2020
    d.toString()// a string-> Sun Nov 01 2020 17:19:16 GMT+0530 (India Standard Time)
    //getFullYear() or setFullYear(2020), values are integers only
      d.getFullYear()//	Get the year as a four digit number (yyyy)
      d.getMonth()//	Get the month as a number (0-11)
      d.getDate()//	Get the day as a number (1-31)
      d.getHours()//	Get the hour (0-23)
      d.getMinutes()//	Get the minute (0-59)
      d.getSeconds()//	Get the second (0-59)
      d.getMilliseconds()//	Get the millisecond (0-999)
      d.getTime()//	Get the time (milliseconds since January 1, 1970)
      d.getDay()//	Get the weekday as a number (0-6)
      // UTC date methods are used for working with UTC dates (Universal Time Zone dates):
        d.getUTCDate()//	Same as getDate(), but returns the UTC date
        d.getUTCDay()//	Same as getDay(), but returns the UTC day
        d.getUTCFullYear()//	Same as getFullYear(), but returns the UTC year
        d.getUTCHours()//	Same as getHours(), but returns the UTC hour
        d.getUTCMilliseconds()//	Same as getMilliseconds(), but returns the UTC milliseconds
        d.getUTCMinutes()//	Same as getMinutes(), but returns the UTC minutes
        d.getUTCMonth()//	Same as getMonth(), but returns the UTC month
        d.getUTCSeconds()	//Same as getSeconds(), but returns the UTC seconds
  // formats
    ISO Date(YYYY-MM-DDTHH:MM:SSZ)	  ->  "2015-03-25T12:00:00Z"(The International Standard)
                    T// separate date to time
                    Z// UTC timeZone
    Short Date(MM/DD/YYYY)	->  "03/25/2015"
    Long Date(MMM DD YYYY) or (DD MMM YYYY)	  -> "Jan 25 2015"  or "25 Jan 2015" or "January 25 2015"
    //UTC (Universal Time Coordinated) is the same as GMT (Greenwich Mean Time).
//simple string <-> base64 string
var base64String = atob('hello'   )//ASCII to binary; returns 'aGVsbG8='
var string       = btoa('aGVsbG8=')//binary to ASCII; returns 'hello'
//scroll
  window.scrollTo(300, 500);//scroll element to (horizontal,vertical) px
  window.scrollBy(100, 20);//scroll element to (horizontal,vertical) px from curent position
    //positive value: forward ; negative value backward from the current position
  elmnt.scrollIntoView();//scroll element to the visible area of window
    elmnt.scrollIntoView(alignTo);
    // alignTo	Optional. A boolean value that indicates the type of the align:
      // true - the top of the element will be aligned to the top of the visible area of the scrollable ancestor
      // false - the bottom of the element will be aligned to the bottom of the visible area of the scrollable ancestor.
      // If omitted, it will scroll to the top of the element.
      // Note: Depending on the layout of other elements, some elements may not be scrolled completely to the top or to the bottom.
  //vertical |
    elmnt.scrollHeight;//gets;returns total vertical height of element in px,including padding, but not the border, scrollbar or margin.
    element.scrollTop=100//gets or sets the pxs the element tobe scrolled
      // If the number is a negative value, the number is set to "0"
      // If the element cannot be scrolled, the number is set to "0"
      // If the number is greater than the maximum allowed scroll amount, the number is set to the maximum number
  //horizontal <--->
    elmnt.scrollWidth;//gets;returns total horizontal width of element in px,including padding, but not the border, scrollbar or margin.
    element.scrollLeft=100//gets or sets the pxs the element tobe scrolled
      // If the number is a negative value, the number is set to "0"
      // If the element cannot be scrolled, the number is set to "0"
      // If the number is greater than the maximum allowed scroll amount, the number is set to the maximum number


element.scrollTop = pixels
// set a time based trigger
var Id = setTimeout(()=>{
  mediaRecorder.stop();   //do this
},  5000,"First param of func()", "Second param of fun()",...);               //after this amount of time 
//clear timeout interation or repetition for safety
clearTimeout(Id)
// set a cyclic time based trigger
//until clearInterval() is called, or the window is closed.
//The ID value returned by setInterval() is used as the parameter for the clearInterval() method.
var Id = setInterval(()=>{
  mediaRecorder.stop();   //do this
  window.location.reload();//auto referesh page after 5sec
}, 5000,"First param of func()", "Second param of fun()",...);               //after every this amount of time 
//clear intervel interation or repetition
clearInterval(Id) 
//sleep(ms)
async sleep(){await new Promise(resolve => setTimeout(resolve, 3));}

window.open() - open a new window
window.close() - close the current window
window.moveTo() - move the current window
window.resizeTo() - resize the current window

// return if devices are available
function hasGetUserMedia(params) {  return !!(navigator.mediaDevices &&navigator.mediaDevices.getUserMedia);  };
// config video and audio
const constraints = {   video: {deviceId: devices[0].deviceId}  };
//get->set->apply constraints
const constraints = track.getConstraints();//get
constraints.facingMode = 'user';//set
track.applyConstraints(constraints);//apply during the stream is being used
// create recoder object

var mimeType = ["video/webm", 
                'video/mp4',//not checked
            "video/mpeg",//notsupported
             "video/webm\;codecs=vp8", 
             "video/webm\;codecs=daala", //notsupported
             "video/webm\;codecs=h264", 
             "audio/webm\;codecs=opus", 
             "audio/webm"];
for (var i in mimeType) { console.log( "Is " + mimeType[i] + " supported? " + (MediaRecorder.isTypeSupported(mimeType[i]) ? "Maybe!" : "Nope")); };
const options = {mimeType: "video/webm\;codecs=vp8",
  audioBitsPerSecond:,      //*1000kbps
  videoBitsPerSecond:,      //*1000*1000Mbps
  bitsPerSecond:,   //this is used for the one which is not defined of audio or video or both
  }
// mediaRecorder is actively using the camera, which takes resources and keeps the camera open (and camera light on) unless mediaRecorder.stop() method is called.
const mediaRecorder = new MediaRecorder(stream, options);//recorder obj// one of : stream , <audio>, <video> or <canvas> element
  mediaRecorder.start(eachBlobDuration*1000);//Begins recording media; this method can optionally be passed a timeslice argument with a value in milliseconds. If this is specified, the media will be captured in separate chunks of that duration, rather than the default behavior of recording the media in a single large chunk.
  mediaRecorder.stop();//Stops recording, at which point a dataavailable event containing the final Blob of saved data is fired. No more recording occurs.
  mediaRecorder.ondataavailable = function(event) {dothis(event.data);};// got called every :endof source stream, stop(),requestData(),start(withTimeOnly)
  mediaRecorder.onstop   = function(event) {'do this'};
  mediaRecorder.onstart  = function(event) {'do this'};
  mediaRecorder.onerror  = function(event) {'do this'};
  mediaRecorder.onpause  = function(event) {'do this'};
  mediaRecorder.onresume = function(event) {'do this'};
  mediaRecorder.isTypeSupported(mimeType)//returns a Boolean value indicating if the given MIME media type is supported by the current user agent. 
  mediaRecorder.ignoreMutedMedia=false//false: record silence for audio and black frames for video when input MediaStreamTrack is muted
  mediaRecorder.mimeType//Returns the MIME type that was selected as the recording container for the MediaRecorder object when it was created.
  mediaRecorder.state//Returns the current state of the MediaRecorder object (inactive, recording, or paused.)
  mediaRecorder.stream//Returns the input stream that was passed into the constructor when the MediaRecorder was created.
  mediaRecorder.videoBitsPerSecond//Returns the video encoding bitrate in use. This may differ from the bit rate specified in the constructor (only if it was provided).
  mediaRecorder.audioBitsPerSecond//Returns the audio encoding bitrate in use. This may differ from the bit rate specified in the constructor (only if it was provided).
  mediaRecorder.pause()//Pauses the recording
  mediaRecorder.requestData()//Requests a Blob containing the saved data received thus far (or since the last time requestData() was called. After calling this method, recording continues, but in a new Blob.
  mediaRecorder.resume()//Resumes recording of media after having been paused.

//  blob  : (Binary Large OBject)
var blob = new Blob(chunks, { 'type' : 'audio/ogg; codecs=opus' });
  var audioURL = URL.createObjectURL(blob);
  var size = blob.size//The size, in bytes, of the data contained in the Blob object.
  var mimeType = blob.type//A string indicating the MIME type of the data contained in the Blob. If the type is unknown, this string is empty. this value can be used as contentType of blob.slice()
  var byteArray =  await blob.arrayBuffer()//(data in binary form):Returns a promise that resolves with an ArrayBuffer containing the entire contents of the Blob as binary data.
  var blb = blob.slice(start, end, contentType)//Returns a new Blob object containing the data in the specified range of bytes of the blob on which it's called.
  var strm = blob.stream()//Returns a ReadableStream that can be used to read the contents of the Blob.
  var txt = await blob.text()//Returns a promise that resolves with a USVString containing the entire contents of the Blob interpreted as UTF-8 text.
// creating html elements
document.createElement('video')
const video = document.querySelector('video');//element must be created before use
// list available devices
var devices = navigator.mediaDevices.enumerateDevices();
// # dict of supported constraints
var supportedConstraints = navigator.mediaDevices.getSupportedConstraints();
// get stream ->display screen
var stream = navigator.mediaDevices.getDisplayMedia(constraints);
// get stream-> webcam|Mic
var stream = navigator.mediaDevices.getUserMedia(constraints);
// get stream from video element
stream = video.captureStream(optional_FPS);
// # set video src to stream
video.srcObject = stream;
//get stream state ;
console.log(stream.active)// ture if stream is active
// get get list of video tracks
var videoTracks = stream.getVideoTracks();//or getAudiTracks()
// get first streaming track
track = videoTracks[0]// get stream track of video|audio Tracks[0]
  track.kind//videoinput or audioinput
  track.label// FaceTime HD Camera (Built-in) etc..// device name
  track.deviceId// csO9c0YpAf274OuCPUA53CNE0YHlIr2yXCi+SqfBZZ8= 
// split audio and video tracks from stream
const vtracks = stream.getVideoTracks();
const atracks = stream.getAudioTracks();
// make stream objects from the tracks
const videoStream = new MediaStream(vtracks);
const audioStream = new MediaStream(atracks);

# %%
#@title ajax
# %%js
//404: 'file not found'      https://www.w3schools.com/tags/ref_httpmessages.asp
//events  https://www.w3schools.com/tags/ref_eventattributes.asp 

//STATIC request is when you try to access a file with an extension (cool-dog.png)
//Download:You send request to the server using JavaScript (ajax for example).
  //In this request you say: "GET http://my-site/images/cool-dog.png" This is static request that try 
  //to access images/cool-dog.png from your public folder on the server. Every server has option that allows
  //you to determinate which folder will contain all the files for the static requests.
// Upload: As we know, everybody can write client-side JavaScript to the console: Every major browser has debugging tools.
  // And everybody can send any kind of request to your server from Postman for example.
  // It will be bad to accept all of there request. Somebody may want to upload 100GB file at max speed.
  // That may affect the application and server performance or even hack the application.
  // You need server-side logic to determinate which file is good for your server and where this file must be stored,
  // since the JavaScript know only about client-side storage (cookies, localStorage, sessionStorage, cache, etc...).
  // Upload process is:
    // You send request from the client-side JavaScript to the server-side. For example : POST http://my-site/uploadImage 
    // with the image data.The server-side accepts that request.For example
    // Router.get('uploadImage', function() {...Server side code...}).
    // Since http://my-site/uploadImage is dynamic path (we do not have extension) The server-side Router will
    // wait for this kind request and if it's requested the server-side code must check the file size and 
    // extension (.png or .dll) and etc... And if the file is good for your application then you can write this
    // file to the server location.
GET: // simpler, faster and less secure than POST
POST: //can be used in most cases. use POST when:
  // A cached file is not an option (update a file or database on the server).
  // Sending a large amount of data to the server (POST has no size limitations).
  // Sending user input (which can contain unknown characters), POST is more robust and secure than GET.
PUT: //calling the same PUT request multiple times will always produce the same result.
  // calling a POST request repeatedly have side effects of creating the same resource multiple times.
HEAD: //HEAD is almost identical to GET, but without the response body.
  // GET /users - returns a list of users and HEAD /users - will make the same request but will not return the list of users.
  // HEAD requests are useful for checking what a GET request will return before actually making a GET request 
  //- like before downloading a large file or response body.
DELETE: // method deletes the specified resource.
OPTIONS: // method describes the communication options for the target resource.
CONNECT: // establishes a tunnel to the server identified by the target resource.
TRACE: // performs a message loop-back test along the path to the target resource.
PATCH: // to apply partial modifications to a resource.
//                                          GET                                                             POST
  BACK button/Reload      	                    Harmless                          Data will be re-submitted (the browser shouldalert the user
                                                                                  that the data are about to be re-submitted)
  Bookmarked                    	Can be bookmarked                                                   	Cannot be bookmarked
  Cached	                        Can be cached	                                                        Not cached
  Encoding type         	    application/x-www-form-urlencoded	                  application/x-www-form-urlencoded or multipart/form-data.
                                                                                  Use multipart encoding for binary data
  History          	          Parameters remain in browser history                                Parameters are not saved in browser history
  Restrictions on data length	        Yes, when sending data, the GET method                        No restrictions
                                      adds the data to the URL; and the 
                                      length of a URL is limited 
                                      (maximum URL length is 2048 characters)
  Restrictions on data type	        Only ASCII characters allowed                                 No restrictions. Binary data is also allowed
  Security	                GET is less secure compared to POST because data      POST is a little safer than GET because the parameters are not stored
                            sent is part of the URL. Never use GET when            in browser history or in web server logs  
                            sending passwords or other sensitive information!
  Visibility          	Data is visible to everyone in the URL                                  Data is not displayed in the URL




var xhttp = new XMLHttpRequest() //	Creates a new XMLHttpRequest object
//object methods
xhttp.abort()	//Cancels the current request
xhttp.open(method, url, async, user, psw)	//Specifies the request
  // method: the request type GET or POST
  // url: the file location|address on server;
    //  any kind of file which can perform actions on the server before sending the response back.
    // .txt, .xml, server scripting files like .asp, .php
  // async: true (asynchronous) or false (synchronous)
    //asynchronous : JavaScript does not have to wait for the server response, but can instead:
      // execute other scripts while waiting for server response or deal with the response after the response is ready.
  // user: optional user name
  // psw: optional password
xhttp.send()	//Sends the request to the server;    Used for GET requests-
xhttp.send("name=bobo&id=28")	//Sends the request to the server.; Used for POST requests
xhttp.setRequestHeader("header name","header value")	//Adds a label-value pair to the header to be sent
//object properties
xhttp.onreadystatechange = function() {--dothis--}
  // When readyState == 4 and status == 200, the response is ready:
  // function to be executed when the request receives an answer or when xhttp.readyState property changes.
  // function is called every time the xhttp.readyState property changes.
  // The onreadystatechange event is triggered four times (1-4), one time for each change in the readyState.
xhttp.readyState	//Holds the status of the XMLHttpRequest.
  // 0: request not initialized
  // 1: server connection established
  // 2: request received
  // 3: processing request
  // 4: request finished and response is ready
xhttp.status	//Returns the status-number of a request
  // 200: "OK"
  // 403: "Forbidden"
  // 404: "Not Found"
  // For a complete list go to the Http Messages Reference
xhttp.statusText	//Returns the status-text (e.g. "OK" or "Not Found")
// Server Response Methods
xhttp.getAllResponseHeaders()	//Returns all header information  from the server resource
xhttp.getResponseHeader("header name")	//Returns specific header information  from the server resource
// Server Response Properties
var type = xhttp.responseType;// get or set the response type returned by the server
xhttp.responseType = 'json';// one of: 'arraybuffer', 'blob', 'document', 'json','text'
xhttp.responseText	//Returns the server response|data as a JavaScript string 
xhttp.responseXML	//Returns the response|data as XML DOM object.
xhttp.response  //Returns an ArrayBuffer, Blob, Document, JavaScript object, or a DOMString, depending on the value of XMLHttpRequest.responseType, that contains the response entity body.

# %%
# @title $jQuery
//jQuery installation or import
  <script src="https://ajax.googleapis.com/ajax/libs/jquery/3.1.0/jquery.min.js"></script>
// the value can be a string ("hello") or a (fun(){return 'hello'})
  $("#p").text('hello') - Sets or returns the text content of selected elements
  $("#p").html("<p>hello</p>") - Sets or returns the content of selected elements (including HTML markup)
  $("#p").val("100") - Sets or returns the value of form fields
  $("#p").attr("href", "https://www.w3schools.com/jquery/")//change attributes values
  //or change multiple attributes
  $("#p").attr({
    "href" : "https://www.w3schools.com/jquery/",
    "title" : "W3Schools jQuery Tutorial"
  });
//POST method
$.post(URL,data,callback);
//GET method
$.get(URL,callback);

# %%
 @title canvasjs charts and visualizaton
# https://canvasjs.com/
# %%javascript
// main script
<script type="text/javascript" src="https://canvasjs.com/assets/script/canvasjs.min.js"></script> //normal
<script type="text/javascript" src="https://canvasjs.com/assets/script/jquery-1.11.1.min.js"></script>  //jquery supuport
<script type="text/javascript" src="https://canvasjs.com/assets/script/jquery.canvasjs.min.js"></script> //jquery supuport
<script type="text/javascript" src="https://canvasjs.com/assets/script/canvasjs.stock.min.js"></script> // stock graph support
// chart definition
let myChart = function () {
     // create chart object
    var chart = new CanvasJS.Chart("chartContainer");//using div id
    var stockChart = new CanvasJS.StockChart("chartContainer");//using div id
      //Note: StockCharts allow you to have one or more Charts rendering different types of data across the same range as shown below.
              // Charts support all the features mentioned in Charts documentation except for two exceptions – Bar Charts & Charts without 
              // an axis like Pie, Funnel, etc are not allowed. Also, all charts sync their Axis Range, ToolTip & Crosshair whenever you interact with any one of the charts.
    chart.options.interactivityEnabled	=	true,//	Enables / Disables Chart interactivity like toolTip, mouse and touch events
    chart.options.animationDuration	=	1200,//	1000, 500, etc	Sets the duration of animation in milliseconds; how fast the chart is updating
    chart.options.animationEnabled	=	false	,//	Enables Animation while rendering the Chart
    chart.options.exportFileName	=	"Chart",//	“Column Chart”, etc	name of the file; stockChart default "StockChart"
    chart.options.exportEnabled	=	false	,//let you save the chart as image
    // Zoom and pan chart
      // When number of dataPoints are large the property is automatically Enabled.
      // This property only works for charts with axis.
      //In StockChart, panning is enabled by default.
      //In regular charts, both panning and zooming are disabled by default.
      chart.options.zoomEnabled	=	false	, //to zoom the chart;	Works with all chart types except Pie And Doughnut; They apply for Chart types that have Axis.
      chart.options.zoomType = "x",//“x”, “y”, “xy”  ; to control the axis for which zooming and panning are enabled. 
    chart.options.backgroundColor =	“#FFFFFF”,//	“yellow”, “#F5DEB3″..	;background color of entire Chart Area. Values can be “HTML Color Name”, “hex code” or “rgba values”
    chart.options.colorSet	=	“colorSet1”	,//“colorSet2”, “colorSet3”	;array of colors that are used to render data; add custom colorset as below
      CanvasJS.addColorSet("my_colorset1", [“#4661EE”,“#EC5657”,“#1BCDD1”,“#8FAABB”,“#B08BEB”,“#3EA0DD”,“#F5A52A”,“#23BFAA”,“#FAA586”,“#EB8CC6”,]);//colorSet Array
    chart.options.culture	=	“en”,//	“es”, etc	; to be used by  chart language-characters-sysmbols; https://canvasjs.com/docs/charts/chart-options/culture/
    chart.options.width	=	500	,//400, 1000 etc	
    chart.options.height =	400	,//400, 300 etc	
    chart.options.dataPointMaxWidth	= 30,//	Automatically calculated based on the chart size	40, 300 etc	;Supported in all types of column,bar-charts,ohlc,candlestick charts
    chart.options.dataPointMinWidth = 50,//dataPointMinWidth should be less than dataPointMaxWidth.
      //Increasing dataPointMinWidth can lead to column/bar overlap when there are large number of dataPoints.
    chart.options.rangeChanging = function (e) {},//  triggered before viewportMinimum or viewPortMaximum are updated while zooming, panning, or reset.
    chart.options.rangeChanged = function (e) {},//  triggered after viewportMinimum or viewPortMaximum are updated while zooming, panning, or reset.
    stockChart.options.rangeSelector = {//to control the range of data being shown in viewport of charts by entering the range manually.
                                        // It comprises of buttons with pre-defined ranges and Inputfields to enter start and end values of range as text.
        enabled	:	true,//	false, true	
        width	:	Takes stockchart container’s width by default,//	400, 800, etc.	
        height	:	Auto calculated based on stock-chart size,//	50, 100, etc.	
        verticalAlign	:	“top”,//	“top”, “bottom”	
        label	:	“Range”,//	“Zoom”, “Range”, etc.	
        selectedRangeButtonIndex	:	None,//	1, 2, etc.
        inputFields: {//to set range of the data to be displayed on all charts.  from [startValue] to [endValue] top-right
          enabled	:	true,//	true, false	
          startValue :Automatically Calculated based on data.,//	20, 100, new Date(2017, 06, 01)	;Number/Date/Timestamp
          endValue :	Automatically Calculated based on data.,//	400, 700, new Date(2017, 09, 04)	;Number/Date/Timestamp
          valueType	:	Automatically Calculated based on data.,//	“number”, “dateTime”	
          valueFormatString	:	null	,//“DD-MM-YYYY”	Auto Formatted
          style: {
              backgroundColor	:	“white”	,//“blue”, “#a0beec”	
              borderColor	:	“#2196f3”	,//“blue”, “#d3d1dc”	
              borderColorOnFocus	:	“#008eff”,//	“black”, “#eaeaea”	
              borderThickness	:	2,//	3, 4	
              fontColor	:	“#000000”,//	“black”, “#d3d1dc”	
              fontSize	:	12,//	1, 2	
              fontStyle	:	“normal”,//	“normal”, “italic” , “oblique”	
              fontFamily	:	“Trebuchet MS, Helvetica,// sans-serif”	“Arial, Trebuchet MS, Tahoma, sans-serif”	
              fontWeight	:	“normal”,//	“lighter”, “normal”, “bold” , “bolder”	
              width	:	Auto Calculated	,//90, 100	
              maxWidth	:	Auto Calculated,//	750, 960	
              padding	:	2,//	6, 10	
              cursor	:	“text”,//	“pointer”, “crosshair”	
            }
          }
        buttonStyle: {//the style of the buttons
          backgroundColor	:	“white”	,//“blue”, “#a0beec”	
          backgroundColorOnHover	:	“#41a5f5” ,//(varies based on themes)	“grey”, “#2196f3”	
          backgroundColorOnSelect	:	“#008eff”	,//“darkSlateBlue”, “#eaeaea”	
          borderColor	:	“#2196f3” ,//(varies based on themes)	“Crimson”, “#41a5f5”	
          borderThickness	:	1,//	2, 4 …	
          labelFontColor	:	“grey”,//	“red”, “#FAC003”	
          labelFontColorOnHover	:	“grey”,//	“yellow”, “#FAC003”	
          labelFontSize	:	Auto Calculated based on Stockchart Size	,//14, 16 …	
          labelFontStyle	:	“normal”,//	“normal”, “italic”, “oblique”	
          labelFontFamily	:	“Calibri,// Optima, Candara, Verdana, Geneva, sans-serif”	“calibri”, “tahoma”, “verdana”	
          labelFontWeight	:	“normal”,//	“lighter”, “normal”, “bold”, “bolder”	
          width	:	Auto Calculated based on Stockchart Size,//	8, 10, 11 …	
          maxWidth	:	Auto Calculated based on Stockchart Size,//	4, 8, 16 …	
          padding	:	{ left: 5, right: 5, top: 2, bottom: 2 },//	{ left: 2, right: 2, top: 2, bottom: 2 }, 2 , 3	
          spacing	:	0,//	1, 3, 4 …	
          cursor	:	“pointer”,//	“pointer”, “move”, “crosshair”	
          }
        buttons: [//buttons array [1D,1W,1M,5M,1Y]
          {//button1
          label	:	Automatically assigned based on the range	,//“1M”, “5M”
          range	:	Auto Calculated based on data	,//1, 4 …; the gap between the range buttons' ranges
          rangeType	:	“month”,//	“numeric”, “millisecond”, “second”, “minute”, “hour”, “day”, “week”, “month”, “year”, “ytd”, “all”
          },{...}...//other buttons
         ]
      }
    stockChart.options.navigator: {//Navigator is used to show a preview of the entire range of data.
                                  //It also allows you to select the range of values to be shown in the viewport of charts.
                                  //If no data is passed to navigator, it takes data from the first chart of the StockChart.
        	enabled	:	true,//false, true	
          height	:	Automatically Calculated based on the Stock Chart height	,//300, 400, 500 …	
          width	:	Automatically Calculated based on the Stock Chart width	,//500, 600, 800 …	
          verticalAlign	:	“bottom”,//“top”, “bottom”	
          backgroundColor	:	null	,//“blue”, “#0000FF”, “rgb(0,0,255)” …	
          animationEnabled	:	false,//	false, true	
          animationDuration	:	1200,//	500, 1000, 1500 …	
          dynamicUpdate	:	true,//	false, true	;When set to false, StockChart will not update till you leave the mouse from Slider.
          slider: {//to slide the selected range only, to be viewed
              maskColor	:	“#d9e8f9”,//	“rgb(100,149,237)”, “#beebe9”
              maskOpacity	:	0.6,//	0.4, 0.5 …
              maskInverted	:	false,//	true, false
              handleColor	:	“#EFEFEF”	,//“rgb(105,105,105)”, “#271b1b”
              handleBorderColor	:	“#3A3A3A”,//	“red”, “yellow” ,”#FF0000″
              handleBorderThickness	:	1,//	1, 2, 3 …
              handleWidth	:	Automatically Calculated based on the navigator width,//	10, 20 …
              handleHeight	:	Automatically Calculated based on the navigator height,//	30, 40 …
              minimum	:	Automatically Calculated based on the data,//	new Date(2018, 03, 12), 120 …;Number / Date / Timestamp
              maximum	:	Automatically Calculated based on the data,//	new Date(2019, 02,03), 250 …; Number / Date / Timestamp
              outlineColor	:	“#666666”	,//#dedede”, “black”
              outlineThickness	:	1,//	1, 2 …
              outlineInverted	:	false,//	true, false
            },
          data :{             // data[dataSeries[dataPoints]]
            //If data is not set in navigator, first dataSeries of first chart is automatically assigned.
            same as chart.options.data
          },
          // or axisX
          axisY:{// set various parameters of Y Axis in Navigator
            same as chart.options.axisY and axisX excluding the crosshair options
            this does not support multiple axises like [{...},{...}...] but only {...} one axis
            }
      }
    stockChart.options.charts[];//array of charts   charts[{title,axisX,data,...},{...}...]
    //axisY  (left), axisY2 (right), axisX (bottom), axisX2 (top)     //Works with all chart types except Pie, Doughnut
    chart.options.axisY = [{
      // title
      title:'axisY line 1',
        titleWrap	:	true,//	true, false	
        titleMaxWidth	:	150,// 200	;Automatically Calculated based on Chart Size
        titleFontColor	:	"black",//	“red”, “#006400” ..
        titleFontSize	:20,//	25, 30 ..;Auto. Calculated
        titleFontFamily	:"arial",//	“arial” , “tahoma”, “verdana” ..
        titleFontWeight	:"normal",//	“lighter”, “normal, “bold”, “bolder”
        titleFontStyle:"normal",//	“normal”,“italic”, “oblique”
      margin	:2,//	10, 12 ..
      // label
        labelPlacement:"outside",//	“outside”, “inside”
        labelTextAlign:"left",//	“left”, “center”, “right”
        labelAngle	:0	,//45,-45, 60 ..
        labelFontFamily	:	“arial”	,//“tahoma”, “verdana” ..
        labelFontColor	:	“black”	,//“red”, “#006400” ..
        labelFontSize	:	12	,//25, 30 ..;Auto. Calculated
        labelFontWeight	:	“normal”	,//“lighter”, “normal, “bold”, “bolder”
        labelFontStyle	:	““normal””,//	“normal”,“italic”, “oblique”
        labelAutoFit	:	true,//	true, false
        labelWrap	:	true	,//true, false
        labelMaxWidth	:	null ,//(auto)	100, 140, etc; Automatically calculated based on the length of label
        labelFormatter	:	null,//	function(e) { }
        labelBackgroundColor:	“transparent”,//	“red”, “#fabd76”
      prefix: "$", suffix: "K" ,
      valueFormatString:  "#,##0.##", // move comma to change formatting; use '' empty to hide axis values only
        ValueFormatString	        Result for(1234567.58)
            #,###.##	          1,234,567.58
            #,###.###	          1,234,567.58
            #,###.##0	          1,234,567.580
            #,###.#	            1,234,567.6
            #,##,###.#	        12,34,567.6
            #,###,.##	          1,234.57
            #,###,.##K	        1,234.57K
            #,###,,.##M	        1.23M
            #,##0,,,.#####G   	0.00123G
            #.00E+0	            1.23E+6
            ##.00E+0	          12.35E+5
            ##.000E+00	        12.346E+05
            hh:mm TT          	10:30 AM
            DD MMM	            15 Aug
            DD-MM-YY	          15-08-16
            DDD HH:mm:ss      	Mon 10:30:00
            DD MMMM YYYY	      15 August 2016
            DDDD MMM YYYY HH:mm:ss k	        Monday Aug 2015 10:30:00 GMT+0530
            D’th’ MMMM hh:mm tt	              15th August 10:30 am
            ‘Morning’ hh ‘hour’ mm ‘minute’	  Morning 10 hour 30 minute
      
            FormatSpecifier	    Name	                  Description	                                                                                    Examples
            “0”       	ZeroPlaceholder	  Replaces the zero with the corresponding digit if one is present; otherwise, zero appears            3182.4123 (“00000”) -> 03182
                                          in the result string.	
            “#”         DigitPlaceholder	Replaces the “#” symbol with the corresponding digit if one is present; otherwise,                      
                                          no digit appears in the result string.	                                                             3182.4123 (“#####”) -> 3182
            “.”	        DecimalPoint	    Determines the location of the decimal separator in the result string.	                             0.3182(“0.00”) -> 0.32
            “,”	        GroupSeparator    Determined the location of the comma separator. .Distance between the commas reading                 10000000 (“#,##,###”) -> 1,00,00,000
                                          from left to right is taken as a scaling parameter. All the numbers after that will                  100000000 (“#,###,##”) -> 1,000,000,00
                                          be grouped based on it.                                                                              10000000 (“####,##”) -> 10,00,00,00
                            and                                                                                                                
                        NumberScaling	    As a number scaling specifier, it divides a number by 1000 for each comma specified                  300000000(“#,,.”) -> 300
                                          next to decimal separator – dot                                                                      
                                                                                                                                              
            “%”	     PercentagePlaceholder	      Multiplies a number by                                                                       100	3(“#%”) -> 300%
            “‰”    	 PerMillePlaceholder	        Multiplies a number by 1000.                                                                 0.0123 (“#0.00‰”) -> 12.30

            “E0”     ExponentialNotation	        If followed by at least one 0 (zero), formats the result using exponential notation.         1503.92311 (“0.0##e+00”) -> 1.504e+03
            “E+0”                                 The case of “E” or “e” indicates the case of the exponent symbol in the result string.       0.0000000232320(“##.000 E+0”) -> 23.232 E-9
            “E-0”                                 The number of zeros following the “E” or “e” character determines the minimum number         10000 (“0.0# e0”) -> 1.0 e4
            “e0”                                  of digits in the exponent.
            “e+0                                  A plus sign (+) indicates that a sign character always precedes the exponent.
            “e-0”                                 A minus sign (-) indicates that a sign character precedes only negative exponents.	         
              
            “string”	LiteralStringDelimiter    	Indicates that the enclosed characters should be copied to the result string unchanged.    	68 (“# ‘%'”) -> 68 %
            Others	  AllOtherCharacters        	The character is copied to the result string unchanged.	                                    34 (“# USD”) -> 34 USD
            “D”	      1-31                        Sun Feb 03 2013 22:04:49 -> 3
            “DD”	    01-31                     	Sun Feb 03 2013 22:04:49 -> 03
            “DDD”	    Sun,Mon..                 	Sun Feb 03 2013 22:04:49 -> Sun
            “DDDD”	  Sunady,Monday...          	Sun Feb 03 2013 22:04:49 -> Sunday
            “M”	      1-12                      	Sun Feb 03 2013 22:04:49 -> 2
            “MM”	    01-12                     	Sun Feb 03 2013 22:04:49 -> 02
            “MMM”	    Jan,Feb...                	Sun Feb 03 2013 22:04:49 -> Feb
            “MMMM”	  Janury,February...        	Sun Feb 03 2013 22:04:49 -> February
            “Y”	      0-99                      	Sun Feb 03 2003 22:04:49 -> 3
            “YY”	    00-99                     	Sun Feb 03 2003 22:04:49 -> 03
            “YYY”	    000-999                   	Sun Feb 03 2003 22:04:49 -> 003
            “YYYY”	  0000-9999                 	Sun Feb 03 2003 22:04:49 -> 2003
            “h”       1-12h                       Sun Feb 03 2013 22:04:49 -> 10
            “hh”	    01-12h                     	Sun Feb 03 2013 22:04:49 -> 10
            “H”	      0-23h                       Sun Feb 03 2013 22:04:49 -> 22
            “HH”	    00-23h                      Sun Feb 03 2013 22:04:49 -> 22
            “m”	      0-59m                       Sun Feb 03 2013 22:04:49 -> 4
            “mm”      00-59m                      Sun Feb 03 2013 22:04:49 -> 04
            “s”	      0-59s                     	Sun Feb 03 2013 22:04:09 -> 9
            “ss”	    00-59s                      Sun Feb 03 2013 22:04:09 -> 09
            “f”	      0-9ms                 	    Sun Feb 03 2013 02:34:49.237 -> 2
            “ff”	    00-99ms 	                 	Sun Feb 03 2013 02:34:49.237 -> 23
            “fff”	    000-999ms	                 	Sun Feb 03 2013 02:34:49.237 -> 237
            “t”	      a-p                       	Sun Feb 03 2013 22:04:09 -> p
            “tt”	    am-pm                   		Sun Feb 03 2013 22:04:09 -> pm
            “T”	      A-P     	                 	Sun Feb 03 2013 22:04:09 -> P
            “TT”	    AM-PM                   		Sun Feb 03 2013 22:04:09 -> PM
            “K”	    TimeZone                  		Sun Feb 03 2013 22:04:49 GMT+0530 -> GMT +0530
            “z”	    HoursOffset of UTC         		Sun Feb 03 2013 22:04:49 GMT+0530 -> +5
            “zz”	  HoursOffset of UTC           	Sun Feb 03 2013 22:04:49 GMT+0530 -> +05
            “zzz”	  Hours,Minutes Offset of UTC   Sun Feb 03 2013 22:04:49 GMT+0530 -> +0530
            “string”  simple string            		Sun Feb 03 2003 22:04:49 (‘Morning’ D) -> Morning 3
            Other 		                          	Sun Feb 03 2003 22:04:49 (“val h:mm”) -> val 10:04
      lineColor	:"black",//	“red”, “#006400” ..
      lineThickness	:1,//	5, 8..
      lineDashType	:"solid",//		“solid”, “shortDash”, “shortDot”, “shortDashDot”, “shortDashDotDot”, “dot”, “dash”, “dashDot”, “longDash”, “longDashDot”, “longDashDotDot”
      logarithmBase	:	10,//	2,10 …	
      logarithmic:false,//	true, false     
      interval: 15,
        //Note that interval property in axis applies to ticks, grid lines, labels and interlaced colors.
      intervalType:	null,//	"25",“number”, “millisecond” , “second”, “minute”, “hour”, “day”, “month” , “year”;  used with interval
      interlacedColor: "#F0F8FF" ,//the gap after every 2nd interval value on the axis, just like Black-White strips
      includeZero:	false,//	true, false; only for axisY and axisY2
      // grid lines
      gridThickness	:	0	,///5, 8..
      gridColor	:	“#A0A0A0”,//	“red”, “#006400” ..
      gridDashType:	“solid”	,//	“solid”, “shortDash”, “shortDot”, “shortDashDot”, “shortDashDotDot”, “dot”, “dash”, “dashDot”, “longDash”, “longDashDot”, “longDashDotDot”
      // ticks
      tickLength: 15,
      tickColor: "DarkSlateBlue" ,
      tickThickness: 5
      tickPlacement	:	“outside”	,//“outside”, “inside”	
      // range
      minimum	:	null,//	-100, 350..;Auto Calculated
      maximum	:null,//	-100, 350..;Auto Calculated
      viewportMinimum	:	null,//	-100, 350..
      viewportMaximum:	null,//	-100, 350..
      reversed:false.//	true, false
      // scaleBreaks                          // breaks the graph from the selected portion, use when graph has different ranges in single chart like 0-10-1000-3400-12000
      scaleBreaks: {autoCalculate	:	false,//	true, false
        collapsibleThreshold	:	“25%”	,//“40%”…	
        maxNumberOfAutoBreaks	:	2	,//0,1,2,3,4
        spacing	:	Automatically Calculated,//	“2%”, 10
        type	:	“straight”,//	“straight”, “wavy”, “zigzag”
        color	:	“#FFFFFF”,//	“green”,”#23EA23″…
        fillOpacity	:	.9,//	.2, .5
        lineThickness	:	2,//	0,1,2..
        lineColor	:	“#E16E6E”,//	“red”, “#A45A23”
        lineDashType	:	“solid”,//	“dot”,”dash” etc.
        customBreaks: [{//specify the ranges on axis to shrink/remove. You can add any number of custom scale breaks.
        	startValue	:	null,//	20
          endValue	:	null,//	30
          type	:	“straight”	,//“straight”, “waved”, “zigzag”
          spacing	:	Automatically Calculated,//	5,10,20
          fillOpacity: .2,//0.0to 1.0
          color	:	“white”	,//“green”,”#23EA23″
          lineColor	:	“red”,//	“green”,”#23EA23″
          lineThickness	:	2,//	4
          lineDashType	:	“solid”,//	“dot”,”dash” etc.
        },
        {startValue	:	null...}...] //another scaleBreak
       }
      // crosshair                              //vertical or horizontal full-line follows the mouse on the grapth
        //In StockChart, crosshair of all the charts are synchronized
        crosshair: {enabled	:	true,//	false, true
          snapToDataPoint	:	false	,//true, false
          color	:	“black”	,//“red”, “#FFF046″…
          opacity	:	1,//	0.5, 0.8,…
          thickness	:	1	,//5,10,20
          lineDashType	:	dash,//	“dot”, “dash”, “dashedDot”,…
          valueFormatString	:	Automatically calculated,//	“#,###.##”, “####.00”
          label	:	“”,//	“Custom Label”, “Crosshair Label”,…
          labelWrap	:	true,//	true,false
          labelMaxWidth	:	Automatically Calculated based on label length,//	100, 200…
          labelBackgroundColor	:	“grey”	,//“black”, “#E8E8E8”,…
          labelFontFamily	:	“arial”,//	“Arial, Trebuchet MS, Tahoma, sans-serif”
          labelFontColor	:	“white”,//	“blue”,”#4135e9″
          labelFontSize	:	12,//	18,19,20,22
          labelFontWeight	:	“normal”,//	“lighter”,”normal”,”bold”,”bolder”
          labelFontStyle	:	“normal”,//	“normal”,”oblique”,”italic”
          labelFormatter	:	function(){}	,
          updated	:	function(){}	,
          hidden	: function(){}	,
      //strip lines                             //used to highlite the selected areas on the chart, can be multiple stripLines
      stripLines:[{	value	:	null,//	12
        startValue	:	null,//	20
        endValue	:	null,//	30
        thickness	:	2	,//5,10,20
        color	:	“orange”,//	“green”,”#23EA23″
        label	:	“”,//	“Threshold”,”Target”
        labelPlacement	:	“inside”,//	“inside”,”outside”
        labelAlign	:	“far”	,//“far”,”center”,”near”
        labelWrap	:	true,//	true,false
        labelMaxWidth	:	Automatically Calculated based on label length,//	100 200…;
        labelBackgroundColor	:	“#eeeeee”,//	“red”,”#fabd76″
        labelFontFamily	:	“arial”,//	“Arial, Trebuchet MS, Tahoma, sans-serif”
        labelFontColor	:	“orange”,//	“blue”,”#4135e9″
        labelFontSize	:	12,//	18,19,20,22
        labelFontWeight	:	“normal”,//	“lighter”,”normal”,”bold”,”bolder”
        labelFontStyle	:	“normal”,//	“normal”,”oblique”,”italic”
        showOnTop	:	false,//	true, false
        lineDashType	:	“solid”,//	“dot”, “dash” etc.
        opacity	:	null,//	.1, .2, .5 etc.
        labelFormatter	: function(){}	
        },
        {value	:	null,....}]//another area to highlight
      {title:'axisY line 2',...},..];//axis can have multiple titles
    // chart themes
    chart.options.theme = "light2"//  “light1”, “light2”, “dark1”, “dark2”
    // Legend
     chart.options.legend = {//a small text with symbol front of it, to refer its dataSeries in the grapth
       	fontSize	:	Auto. Calculated,//	25, 30 ..
       	fontFamily	:"monospace",// sans-serif,arial black”	“arial” , “tahoma”, “verdana” ..
       	fontColor	:	“black”,//	“red”, “yellow” ,”#FF0000″ ..
       	fontWeight	:	“normal”,//	“lighter”, “normal, “bold”, “bolder”
       	fontStyle	:	“normal”,//	“normal”,“italic”, “oblique”
       	verticalAlign	:	“bottom”,//	“top”, “center”, “bottom”
       	horizontalAlign	:	“right”	,//“left”, “center”, “right”
       	cursor	:	“default”,//	“pointer”, “crosshair”, …
       	itemmouseover	:	null,//	function(e) { },
       	itemmousemove	:	null,//	function(e) { },
       	itemmouseout	:	null,//	function(e) { },
       	itemclick	:	null,//	function(e) { },
       	reversed	:	false,//	true, false
       	maxWidth	:	Automatically calculated based on the chart size.,//	200, 300, etc.
       	maxHeight	:	Automatically calculated based on the chart size.,//	200, 300, etc.
       	itemMaxWidth	:	Automatically calculated based on the chart,// size.	200, 300, etc.
       	itemWidth	:	Automatically calculated based on the chart size.,//	200, 300, etc.
       	itemWrap	:	true,//	true, false
       	itemTextFormatter	:	null,//	function(e) {}
       	dockInsidePlotArea	:	false	,// true, false
      }
    // chart title              // can only have one title but multiple subtitles
    chart.options.title = { text: "Fruits sold in First & Second Quarter",//title to be shown on top(default) of the chart
                            //Title can be positioned in 9 different places 
                            // center-center not for stockChart
                            horizontalAlign:center,//left, left,   left, center, center, center, right, right,  right
                            verticalAlign:top,     //top, center, bottom, top,   center, bottom,  top,  center, bottom
                            //others
                            backgroundColor:  null,   	//“red”, “yellow” , “#FF0000”;  stockChart only- default "transparent"
                            borderColor:  "black"	,     //“red”, “yellow” ,”#FF0000″ ..
                            borderThickness:  0,        //2,6 ..
                            cornerRadius: 0,           //5,8, ..
                            fontColor:  "black",        //“red”, “yellow” ,”#FF0000″ ..; stockChart only- default “#3A3A3A”
                            fontFamily: "calibri",     //“arial” , “tahoma”, “verdana” ..
                            fontSize: 20,              //25, 30 ..
                            fontStyle:  "normal",       //“normal”,“italic”, “oblique”
                            fontWeight: "normal"	,     //“lighter”, “normal, “bold”, “bolder”
                            margin:   5,                 //10, 12 ..
                            padding:  0,                //5, 8 ..
                            wrap: true,	              //true, false
                            maxWidth: Automatically calculated based on the chart size.	,//200, 400 etc.
                            dockInsidePlotArea: false,	//true, false
                            }
    chart.options.subtitles=[{text: "This is a Subtitle"..}..]// identical as title with same properties but smaller in size, placed under the title and as many as we want.
    // toolTip
      //stockChart:tooltip of multiple charts are synchronized with each other – which means, if you move/hover mouse
      // on a chart, ToolTip will be shown for all the charts at corresponding x value.
      chart.options.toolTip = {
        content: "{name}: {y}",// to be shown
        animationEnabled	:	true,//	true, false
        enabled	:	true	,//true, false
        shared	:	false,//	true, false
        borderColor	:	“green”,// “#FF0312”..
        fontColor	:	“black”,//	“green”, “#FF0312”..
        fontStyle	:	“italic”,//	“normal”, “italic”,”oblique”
        fontSize	:	14	,//16, 12, etc
        fontFamily	:	"Calibri",// Arial, Georgia, serif”	“arial” , “tahoma”, “verdana” ..
        fontWeight	:	“normal”	,//“lighter”, “normal”, “bold” , “bolder”
        borderThickness	:	2	,//1, 3 etc
        cornerRadius	:	5	,//1, 3 etc
        reversed	:	false	,//true, false
        contentFormatter	:	null,//	 function(e){return ( e.entries[0].dataSeries.name + " " + e.entries[0].dataPoint.y + "" ) ;}//can return Text or HTML Content.
        backgroundColor	:	“white”	,//“black”, “#FFFFFF” etc
      }
    // data             // data[dataSeries[dataPoints]]
    chart.options.data = [];// to put the dataSeries- series1 and series2
    chart.options.data.push(series1); or //chart.options.data[0] = {series1}; // Set/Replace dataSeries
    chart.options.data.push(series2); or //chart.options.data[1] = {series2}; // Set/Replace dataSeries
    //dataSeries| sequence
    var series1 = { //dataSeries - first quarter of the chart    
      name: "Vegs",// name of this dataSeries
      type: "column",   // "column" to "bar", "area", "line" , "pie and more... 
        // Pie and Doughnut cannot be combined with any other type of chart.
        // Bar, Stacked Bar and Stacked Bar 100 cannot be combined with any other type.
        // Stacked charts are Multi-Series charts which show two or more similar set of data together in a single chart. There are two variants of Stacked Charts
        // Stacked Charts: dataPoint does not cover the entire chart space.
          // Supported Stacked charts are stackedArea, stackedColumn, stackedBar.
        // Stacked Chart 100:  dataPoint cover the entire chart space.
          //Supported Stacked 100 Percent Charts are stackedArea100, stackedColumn100, stackedBar100.
        // Note:  When plotting stacked charts, all dataSeries should be of same type.(axis-x1 == axis-x2)
        //  chart types: https://canvasjs.com/docs/charts/chart-types/
      axisXType: "primary",//default:primary; left or right
      axisYType: "secondary",//default:primary; left or right
      axisXIndex: 1,//index:default 0; if there are more than one Y axis than this decides which axis this data belongs to.
      axisYIndex: 1,//index:default 0; if there are more than one Y axis than this decides which axis this data belongs to.
      xValueType: "dateTime",// default:auto; only when giving values in x as dateTime stamps in milliseconds like 324123413243.124
      bevelEnabled:	false,//	true,false	; Applies to all Bar & Column charts
      risingColor:	“white”,//	“red”, “#DD7E86” etc	;risingColor property can only be used with candle stick chart
      fallingColor: "#DD7E86",//;can only be used with waterfall chart.
      color:	From theme,//	“red”,”#1E90FF”..
      lineColor:	From theme,//	“red”,”#1E90FF”..
      lineThickness:	2,//	3,4;  Applies to pie & doughtnut charts
      lineDashType:	“solid”,//	“dot”, “dash”	Sets the Line Dash Type for all Line and Area Charts.      
      connectNullData: true,// connect line with dotted line where dataPoints are missing or not given
      nullDataLineDashType : "dash",// 	“solid”, “dot”...; only for stockChart.options.navigator
      visible	:	true,//	true, false	
      fillOpacity	:	.7,// for Area Charts and 1 for all other chart types	1, .5 etc	
      explodeOnClick:	true,//	true, false	;Applies to Pie And Doughnut
      xValueFormatString	:	null,//	“##.0#”, “DD-MMM-YYYY” etc	; affects the toolTip details
      yValueFormatString	:	null,//	“##.0#” etc	; affects the toolTip details
      zValueFormatString	:	null,//	“##.0#” etc	; z value is used only in Bubble chart ; affects the toolTip details
      percentFormatString	:	null,//	“##.0#” etc	
      startAngle	:	0	,//25,-45,180..	; Applies to onle Pie & Doughnut charts, in Degrees
      click: function(e){},// what should happen when clicking on the dataPoint
      mouseover: function(e){}// what should happen when hovering the cursor on the dataPoint
      mousemove: function(e){}// what should happen when moving the cursor on the dataPoint
      mouseout: function(e){}// what should happen when moving the cursor away from the dataPoint
      cursor:	“default”,//	“pointer”, “crosshair”, etc	Sets cursor type for the dataSeries
      highlightEnabled	:	true,//	false, true	
      // toolTip     // show small floating detail when hover cursor on the graph
      toolTipContent: "x: {x}, y: {y} ",// can use the property names as a keyword.
        : "x:{x}, y: {y} <br/> name: {name}, label:{label}"//other property names
        :"y: <span style='\"'color: red;'\"'>{y}</span>"//Customize the content with any css property using inline CSS.
        : "{x}<br/> <span style='\"'color: {color};'\"'>{name}</span>, <strong>{y}</strong>"//can also use color of dataPoint/dataSeries as keyword {color} as part of CSS.
        : "{label} <hr/> x: {x}, y: {y}"// html5 tags can also be used, like <h1></h1>, <strong></strong>, <br/> , <hr/> etc
        : "<a href = '\"'http://apple.com'\"' target='\"'_blank'\"' >{label} </a> <hr/> x: {x}, y: {y}"// hyperlink in the toolTip. One can use anchor tag and add source as shown below.
        :"{y} / #total = #percent% "// in case of stacked, pie and doughnut charts 
        : "x: {x}, y: {y[0]} , {y[1]} "// can also use properties which are arrays as keywords
        : " x: {x}, y: {y[0]}, {y[1]}, {y[2]}, {y[3]} "//In case of candlestick and ohlc Chart 
      // legend  
        legend:{cursor:	“default”,//	“pointer”, “crosshair”..
          fontSize	:	20	,//25, 30 ..
          fontFamily	:	“calibri”	,//“arial” , “tahoma”, “verdana” ..
          fontColor	:	“black”	,//“red”, “yellow” ,”#FF0000″ ..
          fontWeight:	“normal”	,//“lighter”, “normal, “bold”, “bolder”
          fontStyle	:	““normal””,//	“normal”,“italic”, “oblique”
          markerMargin:	4,//Auto calculated based on fontSize	4, 12..
          itemclick	:	null	,//function (e){….}
          itemmouseover:	null	,//function (e){….}
          itemmousemove	:	null	,//function (e){….}
          itemmouseout	:	null,//	function (e){….}
          reversed	:	false	,//true, false
          maxWidth	:	100,//Automatically calculated based on the chart size.	200, 300, etc.
          maxHeight	:	100,//Automatically calculated based on the chart size.	200, 300, etc.
          itemMaxWidth	:	100,//Automatically calculated based on the chart size.	200, 300, etc.
          itemWidth	:	100,//Automatically calculated based on the chart size.	200, 300, etc.
          itemWrap	:	true	,//true, false
          itemTextFormatter	:	null	,//function(e) {}
          dockInsidePlotArea	:	false,//	true, false
          // Legend can be positioned in 8 different places by combining verticalAlign and horizontalAlign properties
          horizontalAlign: "left", // left, left,    left, center, center, right, right,  right 
          verticalAlign: "center",  // top, center, bottom, top,   bottom,  top,  center, bottom
          }
        legendText: "Vegs",// text to show in legend; by default shows the name of the series
        showInLegend: true, // whether or not  to show the "name:";  Chart Legend that you can position in in 8 different places.
        legendMarkerType	:	“circle”,//	“none”, “circle”, “square”, “cross”, “triangle”
        legendMarkerColor	:	“red”,//”#1E90FF”..
        legendMarkerBorderColor	:	“red”,//”#1E90FF”..
        legendMarkerBorderThickness	:	0,//	2, 4..
      // marker_____________________________ also can be used in dataPoints
        // markers are the symbols to represent the dataPoints or the legends
        // Currently markers are supported in Line Charts, Area Charts, Scatter Charts and Bubble Charts only – not available in Column/Bar charts.
        // To disable marker use markerType as “none”.
        markerType:	“circle”,//	“none”, “circle”, “square”, “cross”, “triangle”, “line”
        markerColor:	'red',//auto. takes dataSeries/dataPoint color	or “red”, “#DEB887”, rgb(255,0,0), …
        markerSize	:	3,//auto. Zero for area chart	or 4,5,10...
        markerBorderColor:	“red”,// “#1E90FF”..
        markerBorderThickness:	1,//	4,6..
      // indexLabel
      indexLabel: "i'm high",// applies to all dataPoints in the series_______________________________ are aslo used in dataPoints with indexLabel
        // use can use – "{x}", "{y}", "{name}", "{label}" , "{color}" etc... to get the value
        //Range Charts have two indexLabels – one for each y value;  "{y[#index]}" 
        // In case of stacked, pie and doughnut charts: "#percent" or "#total"
        indexLabelPlacement	:	“outside”,//	“inside”,”outside”
        indexLabelOrientation	:	“horizontal”,//	“horizontal”,”vertical”
        indexLabelBackgroundColor	:	null	,//“red”,”#1E90FF”..
        indexLabelFontColor	:	“black”,//	“red”,”#1E90FF”..
        indexLabelFontSize	:	12	,//16,20,24..
        indexLabelFontStyle	:	“normal”	,//“normal”, “italic”, “oblique”
        indexLabelFontFamily	:	“arial”	,//“arial”, “calibri”, “tahoma”..
        indexLabelFontWeight	:	“normal”	,//“lighter”, “normal” ,”bold” , “bolder”
        indexLabelLineColor	:	“#808080”,//	“red”, “#1E90FF”..
        indexLabelLineThickness	:	2,//	3,4..
        indexLabelWrap	:	true	,//true,false..
        indexLabelMaxWidth	:	null ,//(auto)	4,20..
        indexLabelLineDashType	:	“solid”,//	“dot”, “dash”.. 	Sets the Dash Type for indexLabel’s line.
        indexLabelFormatter	:	null,//	function(e) { }_______________
    };
    var series2 = { //dataSeries - second quarter 
    ...save as above with desired values
    };
    // dataPoints| values       
    series1.dataPoints = [  //or chart.options.data[0].dataPoints = [
      {x:	null,//	10,20,30 .. | new Date(2012, 12, 15)	;-auto-
       y : null,//	34, 26, 28..	
       z : null,//	240, 300, 400	;Applies only to Bubble Charts
       name	:	auto.,//	“apple”, “mango”	
       label	:	null,//	“label1”,”label2″…	  // label is the name of the point|dataPoint|value
       indexLabel	:	null,//"i'm high", 	“{label}”, “Win”, “x: {x}, y: {y} ”	;Supports Keyword // indexLabel set at top(default of the dataPoint); overides the dataPoints' indexLabel value
       indexLabelWrap	 : 	true,//	true, false	
       indexLabelMaxWidth : Automatically calculated based on the length of indexLabel,//	2, 10, 40 etc	
       indexLabelPlacement	:	“outside”	,//“inside”,”outside”	
       indexLabelOrientation	:	“horizontal”,//	“horizontal”,”vertical”	;Doesn’t apply in pie/doughnut chart
       indexLabelBackgroundColor	:	null,//	“red”,”#1E90FF”..	
       indexLabelFontColor	:	“grey”,//	“red”,”#1E90FF”..	
       indexLabelFontSize : 18,//	16,20,24..	
       indexLabelFontStyle	:	“normal”,//	“normal”, “italic”, “oblique”	
       indexLabelFontFamily	:	"Calibri",// Optima, Candara, Verdana, Geneva, sans-serif”	“arial”, “calibri”, “tahoma”..	
       indexLabelFontWeight	:	“normal”,//	“lighter”, “normal” ,”bold” , “bolder”	
       indexLabelLineColor	:	“lightgrey”	,//“red”, “#1E90FF”..	
       indexLabelLineThickness : 2,//	4,6..	;Applies to pie & doughtnut charts
       toolTipContent	:	auto.,//	“{y} units”	;Supports Keywords
       exploded	 : 	false,//	true, false	;Applies to pie & doughtnut charts
       color	:	from theme,//	“red”,”#1E90FF”..	
       lineColor	:	dataSeries lineColor,//	“red”,”#1E90FF”..	
       lineDashType	:	dataSeries lineDashType,//“dash”, “dot”..	
       legendText	:	“dataPoint1”,// “dataPoint2” ..	“apples”, “oranges” ..	;-auto when not set-
       legendMarkerType	:	“circle”,//	“circle”, “square”, “cross”, “triangle”	
       legendMarkerColor	:	marker Color,//	“red”,”#1E90FF”..	
       legendMarkerBorderColor	:	dataSeries marker Color	,//“red”,”#1E90FF”..	
       legendMarkerBorderThickness : 0,//	2, 4 etc	
       markerType	:	“circle”,//	“circle”, “square”, “cross”, “triangle”	;Applies to line, area, bubble, scatter charts
       markerColor	:	dataSeries Color,//	“red”,”#1E90FF”..Applies to line, area, bubble, scatter charts
       markerSize : auto. Zero for area chart,//	5,10..	;Applies to line, area, bubble, scatter charts
       markerBorderColor	:	dataSeries color.	,//“red”,”#1E90FF”..	;Applies to line, area, bubble, scatter charts
       markerBorderThickness : 1,//	4,6..	;Applies to line, area, bubble, scatter charts
       click : null	,//function(e) { },	
       mouseover : null	,//function(e) { },	
       mouseout : null,//	function(e) { },	
       mousemove : null	,//function(e) { },	
       cursor	:	“default”,//	“pointer”, “crosshair”, etc	Sets cursor type for the dataPoint
       highLightEnabled	 : 	true,//	false, true	Enables or Disables highlighting of dataPoint on mouse hover.
       indexLabelLineDashType	:	“solid”	,//“dot”, “dash”…	
       indexLabelFormatter : null	,//function(e) { }	
       showInLegend	 : 	false,//	true, false
       }
    ];
    series2.dataPoints = [  //or chart.options.data[1].dataPoints = [
      ...same as above with desired values            
    ];
    // Add a new dataPoint to dataPoints array
    chart.options.data[0].dataPoints.push({y: 23});
    // Add/Replace a dataPoint
    chart.options.data[0].dataPoints[3] = {y: 23};  
    // Update an existing dataPoint
    chart.options.data[0].dataPoints[3].y = 27; 
    // show updated chart and every time we update the chart, call the render()!!!
    chart.render();
}

myChart();
//Methods
  //can be used anywhere anytime
  number = CanvasJS.formatNumber(100000,'#,##0.##')//100,000
  date =  CanvasJS.formatDate(new Date(2012, 06, 13),"DD MMM YYYY" ) // 13 Jul 2012
  // only used after chart object created or chart values are set
  chart.render()// apply|update the chart values
  // only used after chart.render()
  value = chart.get(“zoomType”);//returns property value
  chart.set(“zoomEnabled”,// propterty to be set
    true ,// value of the property to be set
    true);//Updates the chart automatically after setting the value;default ture
      //Note:Because the chart updates each time set is called by default, it is recommended to disable auto update 
      // (set updateChart to false) till the last step if you have to set multiple properties. Otherwise it can affect
      //  performance because of repeated chart rendering.
  chart.addTo(“axisY”,//property name
    { title: “Axis Y 2 Title” },//property value
    2,//index at which the peroperty will be set
    true);//Updates the chart automatically after setting the value;default ture
  chart.exportChart({ format: "jpg" //or "png" only
              toDataURL: false,
              fileName: 'Chart'
    });
  chart.print();//to print by printer
  chart.toolTip.showAtX(10,// x value for which toolTip needs to be shown.
    0);//Index of dataseries for which toolTip needs to be shown. By default, dataSeriesIndex is
        //  set to 0. i.e. in case of multi-series chart, toolTip for first dataSeries will be shown. 
        // This parameter is ignored if “shared” property of toolTip is set to true – in which case toolTip content includes data for all the series.
  chart.toolTip.hide();//hide temporarily
  pxl_cord =  chart.axisX[0].convertValueToPixel(20)//pixel cordinates based on the resolution of the chart, not the display device
  value =   chart.axisX[0].convertPixelToValue(250)//pixel cordinates based on the resolution of the chart, not the display device
  bool = chart.axisX[0].crosshair.showAt(10);//show at value of axisX|axisY etc and returns the  bool true if success else false
  chart.axisX[0].crosshair.hide();//hide temporarily
  //delete chart
  chart.destroy();//delete chart object internally
  chart.title.remove();//delete chart property; only works with few or maybe json|dict objects
// sync with all charts when zoom,pan and reset
  var charts = [chart1, chart2]; // add all charts (with axes) to be synced
  function syncHandler(e) { 
      for (var i = 0; i < charts.length; i++) {
          var chart = charts[i];
          if (!chart.options.axisX) chart.options.axisX = {};//if chart does not have axisX
          if (!chart.options.axisY) chart.options.axisY = {};//if chart does not have axisY
          if (e.trigger === "reset") {// reset the charts[i]             
              chart.options.axisX.viewportMinimum = chart.options.axisX.viewportMaximum = null;
              chart.options.axisY.viewportMinimum = chart.options.axisY.viewportMaximum = null;
              chart.render();	
          } else if (chart !== e.chart) {
            // X
            chart.options.axisX.viewportMinimum = e.axisX[0].viewportMinimum;//Min
            chart.options.axisX.viewportMaximum = e.axisX[0].viewportMaximum;//Max
            // Y
            chart.options.axisY.viewportMinimum = e.axisY[0].viewportMinimum;//Min
            chart.options.axisY.viewportMaximum = e.axisY[0].viewportMaximum;//Max
            chart.render();
          }
      }
  }
// use images in charts
  var img_src = "https://canvasjs.com/wp-content/uploads/images/gallery/gallery-overview/apple.png";
  var label = chart.data[0].dataPoints[i].label;//get dataPoint.label
  if(label){ 
    img = $("<img>").attr("src", img_src).attr("class", label).css("display", "none")//create image element
    img.appendTo($("#chartContainer>.canvasjs-chart-container"))//append image element to "canvasjs-chart-container" predifind constant class
  }
  //set image position in chart
    var imageBottom = chart.axisX[0].bounds.y1;// get bounds value of y1
    var imageCenter = chart.axisX[0].convertValueToPixel(//value to Pixel cord.
                                                          chart.data[0].dataPoints[5].x//get value of dataPoint x at index 5
                                                        );
    img.width(chart.dataPointWidth * .5);//change the width of image
    img.height(chart.dataPointWidth * .42);//change the height of image
    img.css({"position": "absolute",    //set css style of image
                          "display": "block",
                          "top": imageBottom  - img.height(),
                          "left": imageCenter - img.width()/2
    });
  chart.render();//update the chart
  //resize image with size of display
  $( window ).resize(function() { --change the position of the image--  });

</script>


// to show the chart using id only
<body> <div id="chartContainer" style="height: 300px; width: 100%;"> </div> </body>

# %%
#@title php
html
body
<?php
# super globals
  $GLOBALS  # used to access global variables from anywhere in the PHP script. any var in $GLOBALS is accessible anywhere.// $GLOBALS['a'] returns value of a
  $_SERVER  #holds information about headers, paths, and script locations.
    $_SERVER['PHP_SELF']	#Returns the filename of the currently executing script
    $_SERVER['GATEWAY_INTERFACE']	#Returns the version of the Common Gateway Interface (CGI) the server is using
    $_SERVER['SERVER_ADDR']	#Returns the IP address of the host server
    $_SERVER['SERVER_NAME']	#Returns the name of the host server (such as www.w3schools.com)
    $_SERVER['SERVER_SOFTWARE']	#Returns the server identification string (such as Apache/2.2.24)
    $_SERVER['SERVER_PROTOCOL']	#Returns the name and revision of the information protocol (such as HTTP/1.1)
    $_SERVER['REQUEST_METHOD']	#Returns the request method used to access the page (such as POST)
    $_SERVER['REQUEST_TIME']	#Returns the timestamp of the start of the request (such as 1377687496)
    $_SERVER['QUERY_STRING']	#Returns the query string if the page is accessed via a query string
    $_SERVER['HTTP_ACCEPT']	#Returns the Accept header from the current request
    $_SERVER['HTTP_ACCEPT_CHARSET']	#Returns the Accept_Charset header from the current request (such as utf-8,ISO-8859-1)
    $_SERVER['HTTP_HOST']	#Returns the Host header from the current request
    $_SERVER['HTTP_REFERER']	#Returns the complete URL of the current page (not reliable because not all user-agents support it)
    $_SERVER['HTTPS']	#Is the script queried through a secure HTTP protocol
    $_SERVER['REMOTE_ADDR']	#Returns the IP address from where the user is viewing the current page
    $_SERVER['REMOTE_HOST']	#Returns the Host name from where the user is viewing the current page
    $_SERVER['REMOTE_PORT']	#Returns the port being used on the user's machine to communicate with the web server
    $_SERVER['SCRIPT_FILENAME']	#Returns the absolute pathname of the currently executing script
    $_SERVER['SERVER_ADMIN']	#Returns the value given to the SERVER_ADMIN directive in the web server configuration file (if your script runs on a virtual host, it will be the value defined for that virtual host) (such as someone@w3schools.com)
    $_SERVER['SERVER_PORT']	#Returns the port on the server machine being used by the web server for communication (such as 80)
    $_SERVER['SERVER_SIGNATURE']	#Returns the server version and virtual host name which are added to server-generated pages
    $_SERVER['PATH_TRANSLATED']	#Returns the file system based path to the current script
    $_SERVER['SCRIPT_NAME']	#Returns the path of the current script
    $_SERVER['SCRIPT_URI']	#Returns the URI of the current page
  $_REQUEST #used to collect form data after submitting an HTML form with method="post".
  $_POST    #used to collect form data after submitting an HTML form with method="post". $_POST is also widely used to pass variables.
  $_GET     #used to collect form data after submitting an HTML form with method="get".  $_GET can also collect data sent in the URL.("test_get.php?subject=PHP&web=W3schools.com")
  $_FILES
  $_ENV
  $_COOKIE  #used to store user info on user computer;  $_COOKIE['name'] returns 'user' or set to something else
    setcookie(    #The setcookie() function must appear BEFORE the <html> tag.
      name,   #"user"
      value,   #"bob"
      expire,   #"3600"  secs after 
      path,
      domain,
      secure,
      httponly);
  $_SESSION #used to store info about user;  A session is started with the session_start() function.;  function must appear BEFORE the <html> tag.
    session_unset()    #remove all session variables
    session_destroy()    # destroy the session

htmlspecialchars() #function converts special characters to HTML entities. This means that it will replace HTML characters
  # like < and > with &lt; and &gt;. This prevents attackers from exploiting the code by injecting HTML or Javascript code (Cross-site Scripting attacks) in forms.
$_SERVER["PHP_SELF"] /* variable can be used by hackers!
  If PHP_SELF is used in your page then a user can enter a slash (/) and then some Cross Site Scripting (XSS) commands to execute.
  Cross-site scripting (XSS) is a type of computer security vulnerability typically found in Web applications. XSS enables attackers to inject
  client-side script into Web pages viewed by other users.
  */
var_dump($x);# returns-  dtype(value);  int(3)
# array() sorting
  sort() - sort arrays in ascending order
  rsort() - sort arrays in descending order
  asort() - sort associative arrays in ascending order, according to the value
  ksort() - sort associative arrays in ascending order, according to the key
  arsort() - sort associative arrays in descending order, according to the value
  krsort() - sort associative arrays in descending order, according to the key

<?
body
html
